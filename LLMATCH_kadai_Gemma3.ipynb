# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudoyan118/llmatch_kadai/blob/main/LLMATCH_kadai_Gemma3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## はじめに
#
# 本ノートブックでは、Googleが提供するマルチモーダルな指示チューニング済みモデル google/gemma-3-4b-it を対象に、以下の2つのタスクに取り組むことを目的とした。
#
#
# **タスク1:事前学習済みモデルの評価**
#
# google/gemma-3-4b-it を以下の日本語VLM評価用ベンチマークにおいて評価する：
# - Heron-Bench
# - JA-VLM-Bench-In-the-Wild
# - JA-VG-VQA-500
#
# **タスク2:ファインチューニングと再評価**
#
# 日本語ビジュアル質問応答データセット line-corporation/JIC-VQA を用いて google/gemma-3-4b-it をファインチューニングし、上記3つのベンチマークを用いて再度評価を行う。</br></br>
# しかし、最終的には全てのタスクを完了することはできなかった。
# 現時点で実施できた内容は以下の通りとなっている：
# * google/gemma-3-4b-itをJA-VLM-Bench-In-the-WildとJA-VG-VQA-500のベンチマークを使って、Rouge-Lで評価する

# %% [markdown]
# ## ライブラリのインストールとバージョン確認

# %%
# !pip install -q transformers accelerate datasets peft bitsandbytes gcsfs evaluate rouge_score
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 65.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/8a/6d/44ad094874c6f1b9c654f8ed939590bdc408349f137f9b98a3a23ccec411/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 13.9 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done

# %%
# バージョン確認したいライブラリ名
target_modules = [
    "transformers",
    "torch",
    "datasets",
    "accelerate",
    "peft",
    "bitsandbytes",
    "fsspec",
    "gcsfs",
    "evaluate",
    "rouge_score"
]

print("=== ライブラリバージョン一覧 ===")

for module_name in target_modules:
    try:
        mod = __import__(module_name)
        print(f"{module_name}: {mod.__version__}")
    except ImportError:
        print(f"{module_name}: インストールされていません")
    except AttributeError:
        print(f"{module_name}: `__version__` が存在しません")
# Out:
# === ライブラリバージョン一覧 ===
# transformers: 4.50.3
# torch: 2.6.0+cu124
# datasets: 3.5.0
# accelerate: 1.5.2
# peft: 0.14.0
# bitsandbytes: 0.45.5
# fsspec: 2024.12.0
# gcsfs: 2024.12.0
# evaluate: 0.4.3
# rouge_score: `__version__` が存在しません

# %% [markdown]
# version属性で取得できないライブラリに対して個別でpip showコマンドを用いて確認する

# %%
# !pip show rouge_score
# Out:
# Name: rouge_score
# Version: 0.1.2
# Summary: Pure python implementation of ROUGE-1.5.5.
# Home-page: https://github.com/google-research/google-research/tree/master/rouge
# Author: Google LLC
# Author-email: rouge-opensource@google.com
# License:
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: absl-py, nltk, numpy, six
# Required-by:

# %% [markdown]
# ## Hugging Faceのアクセストークンログイン

# %%
from huggingface_hub import login
from google.colab import userdata
login(userdata.get("HF_token"))

# %% [markdown]
# ## モデル準備

# %%
# ---------- ライブラリのインポート ----------
import torch
from transformers import AutoProcessor, Gemma3ForConditionalGeneration
from datasets import load_dataset
import evaluate

# ---------- モデル・プロセッサの初期化 ----------
gemma_model_id = "google/gemma-3-4b-it"

gemma_model = Gemma3ForConditionalGeneration.from_pretrained(
    gemma_model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto"
).eval()

gemma_processor = AutoProcessor.from_pretrained(gemma_model_id)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.64G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# processor_config.json:   0%|          | 0.00/70.0 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]

# %% [markdown]
# ## ベンチマーク評価

# %% [markdown]
# ## JA-VLM-Bench-In-the-Wild

# %%
from transformers import AutoProcessor, Gemma3ForConditionalGeneration
def generate_vqa_answer(image, question, gt_answer=None):

    try:
        prompt = (
            "<start_of_image><end_of_image>\n"
            f"この画像について「{question.strip()}」という質問に対して、簡潔に日本語で答えてください。"
        )
        inputs = gemma_processor(
            text=prompt,
            images=image,
            return_tensors="pt"
        )
        inputs = {k: v.to(gemma_model.device) for k, v in inputs.items()}

        with torch.inference_mode():
            outputs = gemma_model.generate(
                **inputs,
                max_new_tokens=100,
                do_sample=False
            )

        pred_answer = gemma_processor.decode(outputs[0], skip_special_tokens=True)
        pred_answer = pred_answer.strip().split("\n")[-1].strip()

    except Exception as e:
        print(f" Error during inference: {e}")
        pred_answer = "ERROR"

    return {
        "question": question,
        "gt_answer": gt_answer,
        "pred_answer": pred_answer.strip()
    }

# %%
def infer_ja_vg_vqa500(dataset, image_field="image", qa_field="qas"):
    results = []

    for img_idx, item in enumerate(dataset):
        image = item[image_field].convert("RGB")

        print(f"\n====== [VQA] Image {img_idx} の質問処理 ======")

        for qa_idx, qa in enumerate(item[qa_field]):
            question = qa["question"]
            gt_answer = qa.get("answer", None)

            result = generate_vqa_answer(image, question, gt_answer)
            results.append(result)

            # 中間出力（統一形式）
            print(f"[Image {img_idx} | QA {qa_idx}] 質問: {question}")
            print(f"           正解      : {gt_answer}")
            print(f"           生成回答  : {result['pred_answer']}\n")

    return results

# %%
# ---------- 評価処理（ROUGE） ----------
def evaluate_metric(results, bench_name):
    """
    推論結果を ROUGE-L で評価する。
    """
    rouge = evaluate.load("rouge")

    # 有効なペアのみ抽出
    valid_pairs = [
        (r["pred_answer"], r["gt_answer"])
        for r in results
        if r["gt_answer"] is not None and r["pred_answer"] != "ERROR"
    ]

    if not valid_pairs:
        print(f"[Warning] {bench_name} に評価可能な結果がありません。")
        return

    predictions, references = zip(*valid_pairs)

    print(f"\n Evaluation for {bench_name} (ROUGE-L)")

    score = rouge.compute(
        predictions=predictions,
        references=references,
        rouge_types=["rougeL"]
    )

    print(f" - Rouge-L Score : {score['rougeL']:.4f}")

# %%
from datasets import load_dataset
# ========= 評価開始 ==========
# 1. JA-VG-VQA-500
vg_dataset = load_dataset("SakanaAI/JA-VG-VQA-500", split="test")

# %%
vg_dataset
# Out:
# Dataset({
#     features: ['image_id', 'url', 'width', 'height', 'coco_id', 'flickr_id', 'qas', 'image'],
#     num_rows: 500
# })

# %%
vg_results = infer_ja_vg_vqa500(vg_dataset)
# Out:
# ====== [VQA] Image 0 の質問処理 ======
# [Image 0 | QA 0] 質問: 場所はどこになりますか？
#            正解      : 車のある屋外の場所
#            生成回答  : この画像は、オーストラリアの海岸沿いの道路に駐車された白いトラックの前に置かれたサーフボードを撮影したものです。背景には海と砂浜が見えます。
#
# [Image 0 | QA 1] 質問: 時間帯はいつごろですか？
#            正解      : 昼間
#            生成回答  : 時間帯は不明
#
# [Image 0 | QA 2] 質問: どんな天気をしていますか？
#            正解      : 晴れている
#            生成回答  : 晴れです。
#
# [Image 0 | QA 3] 質問: 車は何台ありますか？
#            正解      : 1台
#            生成回答  : 1台です。
#
# [Image 0 | QA 4] 質問: 車はどんな色をしていますか？
#            正解      : 白色
#            生成回答  : 白い車です。
#
# [Image 0 | QA 5] 質問: サーフボードはいくつありますか？
#            正解      : 1つ
#            生成回答  : 画像にはサーフボードが1枚あります。
#
# [Image 0 | QA 6] 質問: サーフボードはどんな色をしていますか？
#            正解      : 白色
#            生成回答  : サーフボードは白です。
#
# [Image 0 | QA 7] 質問: 車の向こう側には何が見えますか？
#            正解      : 青い海と青い空が広がっているのが見える
#            生成回答  : 車の向こう側には、海と砂浜が見えます。
#
#
# ====== [VQA] Image 1 の質問処理 ======
# [Image 1 | QA 0] 質問: ここはどこですか？
#            正解      : 池のほとりです。
#            生成回答  : この画像は、イギリスのロンドンにある、ボタニック・ガーデンに隣接する、リバー・グレン（River Glen）の風景です。
#
# [Image 1 | QA 1] 質問: 池には何がいますか？
#            正解      : 鴨がいます。
#            生成回答  : 池には、水面に浮かぶアヒルがいます。
#
# [Image 1 | QA 2] 質問: 鴨はどれくらいいますか？
#            正解      : 三羽います。
#            生成回答  : 3羽です。
#
# [Image 1 | QA 3] 質問: 池のほとりには何がいますか？
#            正解      : 犬がいます。
#            生成回答  : 池のほとりには、犬と数羽の鴨があります。
#
# [Image 1 | QA 4] 質問: 犬はどれくらいいますか？
#            正解      : 一匹だけです。
#            生成回答  : 3匹の鴨と1匹のコッカー・スパニエルがいます。
#
# [Image 1 | QA 5] 質問: 犬は何色ですか？
#            正解      : 茶色です。
#            生成回答  : 赤色です。
#
# [Image 1 | QA 6] 質問: 犬は何をしていますか？
#            正解      : 植物の匂いを嗅いでいます。
#            生成回答  : 犬は水辺で水遊びをしています。
#
# [Image 1 | QA 7] 質問: 天気はどうなっていますか？
#            正解      : 曇りです。
#            生成回答  : 曇り空です。
#
#
# ====== [VQA] Image 2 の質問処理 ======
# [Image 2 | QA 0] 質問: ベッドは何台ありますか？
#            正解      : １台
#            生成回答  : 2台のベッドがあります。
#
# [Image 2 | QA 1] 質問: ベッドはどこにありますか？
#            正解      : 室内
#            生成回答  : ベッドは、部屋の左側にあります。
#
# [Image 2 | QA 2] 質問: ベッドシーツは何色ですか？
#            正解      : 紺色
#            生成回答  : ベッドシーツは紫と青です。
#
# [Image 2 | QA 3] 質問: 掛け布団は何色ですか？
#            正解      : 水色
#            生成回答  : 紫と青のグラデーションです。
#
# [Image 2 | QA 4] 質問: 枕はいくつありますか？
#            正解      : １つ
#            生成回答  : 3つ
#
# [Image 2 | QA 5] 質問: 枕はどこにありますか？
#            正解      : ベッドの上
#            生成回答  : 枕はベッドの中にあります。
#
# [Image 2 | QA 6] 質問: 枕は何色ですか？
#            正解      : 白色
#            生成回答  : 紫と白です。
#
# [Image 2 | QA 7] 質問: テレビは何台ありますか？
#            正解      : １台
#            生成回答  : 27台
#
#
# ====== [VQA] Image 3 の質問処理 ======
# [Image 3 | QA 0] 質問: 画像に写っている建物はどこの国にありますか
#            正解      : アメリカ
#            生成回答  : アメリカ合衆国
#
# [Image 3 | QA 1] 質問: 画像に写っている建物はどこの州にありますか
#            正解      : マサチューセッツ州
#            生成回答  : ニューヨーク州
#
# [Image 3 | QA 2] 質問: 画像の手前に写る機械は何ですか
#            正解      : パーキングメーター
#            生成回答  : 公園の駐車場に設置された2つのコインパーキングメーターです。
#
# [Image 3 | QA 3] 質問: 画像のお店のテントに書かれているのはどんなイラストですか
#            正解      : 魚
#            生成回答  : お店のテントには、魚とユダヤ人の文字が描かれた円形のイラストがあります。
#
# [Image 3 | QA 4] 質問: 画像に写っているお店のネオン管で画像に向かって一番左に表示されているものは何ですか
#            正解      : Ｐｉｚｚａ
#            生成回答  : 「Pizza Fish Pasta」と表示されています。
#
# [Image 3 | QA 5] 質問: 画像に写っているお店のネオン管で真ん中に表示されているものは何ですか
#            正解      : Ｆｉｓｈ
#            生成回答  : ピザ、魚、パスタ
#
# [Image 3 | QA 6] 質問: 画像に写っているお店のネオン管で画像に向かって一番右に表示されているものは何ですか
#            正解      : Ｐａｓｔａ
#            生成回答  : 画像に向かって一番右に表示されているものは、駐車場のメーターです。
#
# [Image 3 | QA 7] 質問: 画像に写るお店の名前は何ですか
#            正解      : Ｃａｆｅ Ｅｉｌａｔ
#            生成回答  : カフェエilat
#
#
# ====== [VQA] Image 4 の質問処理 ======
# [Image 4 | QA 0] 質問: 動物の姿は、いくつ見えますか？。
#            正解      : ２頭です。
#            生成回答  : 2
#
# [Image 4 | QA 1] 質問: 見えている動物は、何という名前ですか？。
#            正解      : 象です。
#            生成回答  : エレファント
#
# [Image 4 | QA 2] 質問: 見えている動物は、どこの上に立っていますか？。
#            正解      : 柵の中の地面の上です。
#            生成回答  : 左の象が、右の象の上に立っています。
#
# [Image 4 | QA 3] 質問: 右の動物の肌の色は何色ですか？。
#            正解      : 灰色です。
#            生成回答  : 灰色です。
#
# [Image 4 | QA 4] 質問: 左の動物の肌の色は何色ですか？。
#            正解      : 灰色です。
#            生成回答  : 灰色です。
#
# [Image 4 | QA 5] 質問: 右の動物の顔から出ている長い物は、何という物ですか？。
#            正解      : 鼻です。
#            生成回答  : 鼻
#
# [Image 4 | QA 6] 質問: 左の動物の顔から出ている長い物は、何という物ですか？。
#            正解      : 鼻です。
#            生成回答  : 鼻
#
# [Image 4 | QA 7] 質問: 動物の手前にある柱の色は何色ですか？。
#            正解      : 灰色です。
#            生成回答  : 灰色です。
#
#
# ====== [VQA] Image 5 の質問処理 ======
# [Image 5 | QA 0] 質問: 標識はいくつありますか？
#            正解      : 3つ
#            生成回答  : 2つ
#
# [Image 5 | QA 1] 質問: 一番下の標識は何色ですか？
#            正解      : 赤
#            生成回答  : 赤色です。
#
# [Image 5 | QA 2] 質問: 一番下の標識の枠は何色ですか？
#            正解      : 白
#            生成回答  : 緑色です。
#
# [Image 5 | QA 3] 質問: 一番下の標識の文字は何色ですか？
#            正解      : 白
#            生成回答  : 緑色です。
#
# [Image 5 | QA 4] 質問: 一番下の標識はどんな形ですか？
#            正解      : 八角形
#            生成回答  : 赤い丸の中に「ORD」と書かれた停止標識です。
#
# [Image 5 | QA 5] 質問: 一番上の標識は何色ですか？
#            正解      : 緑
#            生成回答  : 緑色です。
#
# [Image 5 | QA 6] 質問: 上から二番目の標識は何色ですか？
#            正解      : 緑
#            生成回答  : 赤色です。
#
# [Image 5 | QA 7] 質問: 一番上の標識はどんな形ですか？
#            正解      : 長方形
#            生成回答  : 標識は、停止標識と住所標識が組み合わさった形です。
#
#
# ====== [VQA] Image 6 の質問処理 ======
# [Image 6 | QA 0] 質問: 全部で何人の人がいますか？
#            正解      : 3人
#            生成回答  : 3人です。
#
# [Image 6 | QA 1] 質問: ベンチに座っている女性の人数はいくつですか？
#            正解      : 2人
#            生成回答  : 3人です。
#
# [Image 6 | QA 2] 質問: ベンチに座っている女性のうち、左の人が着ているコートの色は何色ですか？
#            正解      : 白色
#            生成回答  : ベージュ
#
# [Image 6 | QA 3] 質問: ベンチに座っている女性のうち、右の人が抱えているカバンの色はどんな色ですか？
#            正解      : 茶色
#            生成回答  : 茶色です。
#
# [Image 6 | QA 4] 質問: ベンチに座っている女性のうち、右の人が着ている上着の色は何色ですか？
#            正解      : 黒色
#            生成回答  : 茶色です。
#
# [Image 6 | QA 5] 質問: 女性が座っているベンチの色はどんな色ですか？
#            正解      : 焦げ茶色
#            生成回答  : ベンチは茶色です。
#
# [Image 6 | QA 6] 質問: 男性が肩に掛けているカバンの色はどんな色ですか？
#            正解      : 緑色
#            生成回答  : 緑色です。
#
# [Image 6 | QA 7] 質問: 男性がはいているズボンの色は何色ですか？
#            正解      : 青色
#            生成回答  : 青色です。
#
#
# ====== [VQA] Image 7 の質問処理 ======
# [Image 7 | QA 0] 質問: この人の性別は何ですか
#            正解      : 女性
#            生成回答  : 女性です。
#
# [Image 7 | QA 1] 質問: 天気は何ですか
#            正解      : 晴れ
#            生成回答  : 晴れです。
#
# [Image 7 | QA 2] 質問: 女性は何をかけていますか
#            正解      : サングラス
#            生成回答  : 女性は凧をかけています。
#
# [Image 7 | QA 3] 質問: 女性の髪の毛の色は何色ですか
#            正解      : 茶色
#            生成回答  : 茶色
#
# [Image 7 | QA 4] 質問: 女性は何を持っていますか
#            正解      : 凧
#            生成回答  : 女性は凧を持っています。
#
# [Image 7 | QA 5] 質問: たこの足は何色ですか
#            正解      : 黄色
#            生成回答  : たこの足は、緑、青、黄色、オレンジ、赤の5色です。
#
# [Image 7 | QA 6] 質問: ここはどこですか
#            正解      : 公園
#            生成回答  : この画像は、公園の芝生の上で凧を飛ばしている女性のものです。背景には、木々、車、そして街並みが写っています。
#
# [Image 7 | QA 7] 質問: 女性はどこに居ますか
#            正解      : 芝生の上
#            生成回答  : 女性は公園にいます。
#
#
# ====== [VQA] Image 8 の質問処理 ======
# [Image 8 | QA 0] 質問: ベッドはいくつありますか？
#            正解      : ３つ
#            生成回答  : ベッドは1つあります。
#
# [Image 8 | QA 1] 質問: ベッドに合計で枕はいくつありますか？
#            正解      : ３つ
#            生成回答  : 2つ
#
# [Image 8 | QA 2] 質問: 枕はどんな色をしていますか？
#            正解      : 白色
#            生成回答  : 枕は白です。
#
# [Image 8 | QA 3] 質問: ランプはいくつありますか？
#            正解      : １つ
#            生成回答  : 3つ
#
# [Image 8 | QA 4] 質問: ランプはどんな状態ですか？
#            正解      : 点灯している
#            生成回答  : ランプは、テーブルの上に置かれており、点灯しています。
#
# [Image 8 | QA 5] 質問: 壁はどんな素材で出来ていますか？
#            正解      : 木
#            生成回答  : 壁は木製です。
#
# [Image 8 | QA 6] 質問: ここはどこ（室内・屋外）ですか？
#            正解      : 室内
#            生成回答  : ここは、木造の屋根裏部屋です。
#
# [Image 8 | QA 7] 質問: ドアはどれくらい設置されていますか？
#            正解      : １つ
#            生成回答  : ドアは壁に設置されています。
#
#
# ====== [VQA] Image 9 の質問処理 ======
# [Image 9 | QA 0] 質問: 背景はどんな色ですか？
#            正解      : 黒色
#            生成回答  : 黒と灰色です。
#
# [Image 9 | QA 1] 質問: どれくらいの種類の動物が居ますか？
#            正解      : 一種類
#            生成回答  : この画像には、2匹のゼブラが居ます。
#
# [Image 9 | QA 2] 質問: どんな名前の動物ですか？
#            正解      : 縞馬
#            生成回答  : ゼブラです。
#
# [Image 9 | QA 3] 質問: 縞馬は全部で何頭ですか？
#            正解      : 三頭
#            生成回答  : 画像には、縞馬が3頭写っています。
#
# [Image 9 | QA 4] 質問: 縞馬の体はどこを向いてますか？
#            正解      : 後ろ
#            生成回答  : 縞馬の体は、どちらか一方の縞馬を向いています。
#
# [Image 9 | QA 5] 質問: 振り向いている縞馬はどれくらい居ますか？
#            正解      : １頭
#            生成回答  : 画像には、2匹の縞馬がいます。
#
# [Image 9 | QA 6] 質問: 振り向いている縞馬はどこに居ますか？
#            正解      : 真ん中
#            生成回答  : 画像には、2匹の縞馬が写っています。1匹は後ろを向いており、もう1匹は前に向いています。
#
# [Image 9 | QA 7] 質問: 振り向いている縞馬は顔のどこが見えてますか？
#            正解      : 右側
#            生成回答  : 顔の右側が見えています。
#
#
# ====== [VQA] Image 10 の質問処理 ======
# [Image 10 | QA 0] 質問: 前の建物の入り口はいくつありますか？
#            正解      : ３つ
#            生成回答  : 3つ
#
# [Image 10 | QA 1] 質問: 建物のドアは何色ですか？
#            正解      : 茶色
#            生成回答  : 黒色です。
#
# [Image 10 | QA 2] 質問: 手前の地面の矢印はどんな形状ですか？
#            正解      : 線の途中で曲がった形状
#            生成回答  : 三角形です。
#
# [Image 10 | QA 3] 質問: 奥の一番高い建物の屋根は何色ですか？
#            正解      : グレー
#            生成回答  : 白です。
#
# [Image 10 | QA 4] 質問: 手前の建物の中間部分からやや下の窓の横側の壁面は主に何色ですか？
#            正解      : 白色
#            生成回答  : 白っぽいベージュ色です。
#
# [Image 10 | QA 5] 質問: 手前の建物の屋根の一番上には何がありますか？
#            正解      : 十字架
#            生成回答  : 手前の建物の屋根の一番上には、時計台があります。
#
# [Image 10 | QA 6] 質問: 手前の建物の中間の入り口の前には何がありますか？
#            正解      : バイク
#            生成回答  : バイクがあります。
#
# [Image 10 | QA 7] 質問: 手前の建物の中間の入り口の上の屋根はその下部と合わせてどんな形状ですか？
#            正解      : 三角形
#            生成回答  : 屋根は、三角形の頂上と、その頂上から伸びる2本の翼を持つ、複雑な形状をしています。
#
#
# ====== [VQA] Image 11 の質問処理 ======
# [Image 11 | QA 0] 質問: 芝生の上にいる動物は何ですか？
#            正解      : 鳥
#            生成回答  : 画像には、芝生の上に2羽の鳩がいます。
#
# [Image 11 | QA 1] 質問: その動物はいくついますか？
#            正解      : ２羽
#            生成回答  : 2羽
#
# [Image 11 | QA 2] 質問: その動物は何色ですか？
#            正解      : グレー
#            生成回答  : 黒色です。
#
# [Image 11 | QA 3] 質問: 植えてある木の葉っぱの色は何色ですか？
#            正解      : 緑色
#            生成回答  : 緑色です。
#
# [Image 11 | QA 4] 質問: 木の後ろに建っている建物は何ですか？
#            正解      : ビル
#            生成回答  : それは、ニューヨーク州の州庁です。
#
# [Image 11 | QA 5] 質問: 木の高さはビルの階層であらわすとどれくらいですか？
#            正解      : ビルの２階相当
#            生成回答  : 木の高さはビルの階層であらわすと、約3階程度です。
#
# [Image 11 | QA 6] 質問: 画像の時間帯はいつですか？
#            正解      : 昼間
#            生成回答  : この画像は、春の日の午後、日中の写真です。
#
# [Image 11 | QA 7] 質問: 天気はどんな天気ですか？
#            正解      : 晴れ
#            生成回答  : 曇り
#
#
# ====== [VQA] Image 12 の質問処理 ======
# [Image 12 | QA 0] 質問: 男性はどんな髪型ですか。
#            正解      : ショートヘアです。
#            生成回答  : 彼は短髪で、少し前髪があります。
#
# [Image 12 | QA 1] 質問: 男性のメガネのフレームは何色ですか。
#            正解      : 黒です。
#            生成回答  : シルバーです。
#
# [Image 12 | QA 2] 質問: 男性はどういう表情をしていますか。
#            正解      : 微笑んでいます。
#            生成回答  : 彼は笑顔で、楽しそうに見えます。
#
# [Image 12 | QA 3] 質問: 男性が着ている物は何ですか。
#            正解      : スーツです。
#            生成回答  : 男性は、黒のスーツ、白のシャツ、縞模様のネクタイを着ています。
#
# [Image 12 | QA 4] 質問: 男性が締めているネクタイのベースの色は何ですか。
#            正解      : グレーか薄いブルーです。
#            生成回答  : 黒です。
#
# [Image 12 | QA 5] 質問: 男性が着ているカッターシャツは何色ですか。
#            正解      : 白地にグレーや茶色のストライプが入ったものです。
#            生成回答  : 白とストライプです。
#
# [Image 12 | QA 6] 質問: 男性が着ているスーツは何色ですか。
#            正解      : 黒色及び黒系のものです。
#            生成回答  : 黒色です。
#
# [Image 12 | QA 7] 質問: 画像には木の梁のような物が写っていますが、男性から見てどこにありますか。
#            正解      : 男性の頭上にあります。
#            生成回答  : 男性の右側にあります。
#
#
# ====== [VQA] Image 13 の質問処理 ======
# [Image 13 | QA 0] 質問: 自転車に乗っている人の服は何色ですか？
#            正解      : 青色
#            生成回答  : 青とオレンジ色のシャツを着ています。
#
# [Image 13 | QA 1] 質問: どんな天気ですか？
#            正解      : 晴れ
#            生成回答  : 晴れです。
#
# [Image 13 | QA 2] 質問: 歩いている男性の服は何色ですか？
#            正解      : オレンジ色
#            生成回答  : 青とオレンジ色のシャツを着ています。
#
# [Image 13 | QA 3] 質問: 歩いている男性は右手に何を持っていますか？
#            正解      : 袋
#            生成回答  : 男性は右手に自転車の鍵を持っています。
#
# [Image 13 | QA 4] 質問: 自動車はいくつ写っていますか？
#            正解      : １つ
#            生成回答  : 0個
#
# [Image 13 | QA 5] 質問: 写っている自動車の色は何色ですか？
#            正解      : 白
#            生成回答  : 青色です。
#
# [Image 13 | QA 6] 質問: 右手の噴水のモニュメントの色は何色ですか？
#            正解      : 灰色
#            生成回答  : 緑色です。
#
# [Image 13 | QA 7] 質問: 自転車に乗っている男性の下の道は何色ですか？
#            正解      : オレンジ色
#            生成回答  : 灰色と茶色です。
#
#
# ====== [VQA] Image 14 の質問処理 ======
# [Image 14 | QA 0] 質問: どんな乗り物が走っていますか？
#            正解      : 大型トラック
#            生成回答  : バスです。
#
# [Image 14 | QA 1] 質問: 大型トラックは、何色ですか？
#            正解      : 3色
#            生成回答  : 赤と黄色です。
#
# [Image 14 | QA 2] 質問: 大型トラックには、何色が使われていますか？
#            正解      : 白色・黄色・オレンジ色
#            生成回答  : 赤、黄色、白です。
#
# [Image 14 | QA 3] 質問: 大型トラックは、何台走っていますか？
#            正解      : 1台
#            生成回答  : 1台の大型トラックが走っています。
#
# [Image 14 | QA 4] 質問: 大型トラックは、どこを走っていますか？
#            正解      : 山中の道路
#            生成回答  : 大型トラックは、舗装された道路と未舗装の道路が混在する道路を走っています。
#
# [Image 14 | QA 5] 質問: 大型トラックにライトは、いくつ付いていますか？
#            正解      : 4つ
#            生成回答  : 4つ
#
# [Image 14 | QA 6] 質問: 大型トラックのライトは、いくつ点いていますか？
#            正解      : 2つ
#            生成回答  : 4つのライトです。
#
# [Image 14 | QA 7] 質問: 大型トラックの点いているライトは、どこにありますか？
#            正解      : フロントバンパーの両端
#            生成回答  : トラックのフロントにあります。
#
#
# ====== [VQA] Image 15 の質問処理 ======
# [Image 15 | QA 0] 質問: 室内ですか室外ですか
#            正解      : 室内
#            生成回答  : 室内です。
#
# [Image 15 | QA 1] 質問: 室内は明るいですか暗いですか
#            正解      : 暗い
#            生成回答  : 暗いです。
#
# [Image 15 | QA 2] 質問: 何が写っていますか
#            正解      : パソコン
#            生成回答  : ノートパソコンの画面に、Windowsのデスクトップ環境が表示されています。画面には、いくつかのアイコンやウィンドウが表示されており、作業中のようです。
#
# [Image 15 | QA 3] 質問: 何が写っていますか
#            正解      : 机
#            生成回答  : ノートパソコンの画面に、Windowsのデスクトップ環境が表示されています。画面には、いくつかのアイコンやウィンドウが表示されており、作業中のようです。
#
# [Image 15 | QA 4] 質問: パソコンはデスクトップですかノートですか
#            正解      : ノート
#            生成回答  : これはノートパソコンです。
#
# [Image 15 | QA 5] 質問: 何色ですか
#            正解      : 黒
#            生成回答  : 黒色です。
#
# [Image 15 | QA 6] 質問: 机の上は整頓されていますか
#            正解      : されていない
#            生成回答  : いいえ。
#
# [Image 15 | QA 7] 質問: 人は写っていますか
#            正解      : 写っていない
#            生成回答  : はい、写っています。
#
#
# ====== [VQA] Image 16 の質問処理 ======
# [Image 16 | QA 0] 質問: 手前でジャンプしている少年の前には何がありますか？
#            正解      : スケートボード
#            生成回答  : 手前でジャンプしている少年には、スランプ、ステップ、そして他のスケーターがいます。
#
# [Image 16 | QA 1] 質問: 後ろのコンクリートの斜面には何が設置されていますか？
#            正解      : 手すり
#            生成回答  : コンクリートの斜面には、階段といくつかのバンクが設置されています。
#
# [Image 16 | QA 2] 質問: ジャンプしている少年は頭に何を被っていますか？
#            正解      : 帽子
#            生成回答  : 帽子を被っています。
#
# [Image 16 | QA 3] 質問: ジャンプしている少年はどんな靴を履いていますか？
#            正解      : スニーカー
#            生成回答  : 彼はスニーカーを履いています。
#
# [Image 16 | QA 4] 質問: 少年が履いているスニーカーの靴紐は何色ですか？
#            正解      : 白色の靴紐
#            生成回答  : 緑と黒です。
#
# [Image 16 | QA 5] 質問: ジャンプしている少年は何色の服を着ていますか？
#            正解      : 紺色の服
#            生成回答  : 黒いフード付きジャケットとジーンズを着ています。
#
# [Image 16 | QA 6] 質問: ジャンプしている少年は何色の帽子を被っていますか？
#            正解      : 黒色の帽子
#            生成回答  : 青色の帽子を被っています。
#
# [Image 16 | QA 7] 質問: 左側にある建物には煙突が何塔ありますか？
#            正解      : 1塔
#            生成回答  : 3塔あります。
#
#
# ====== [VQA] Image 17 の質問処理 ======
# [Image 17 | QA 0] 質問: ここはどこですか？
#            正解      : 屋外
#            生成回答  : ここは、霧が立ち込める海岸の砂浜です。
#
# [Image 17 | QA 1] 質問: これはいつですか？
#            正解      : 日中
#            生成回答  : 2023年10月27日
#
# [Image 17 | QA 2] 質問: 天気はどうですか？
#            正解      : くもり
#            生成回答  : 霧がかった日です。
#
# [Image 17 | QA 3] 質問: 空はどんな風ですか？
#            正解      : 一面雲に覆われている
#            生成回答  : 空は灰色です。
#
# [Image 17 | QA 4] 質問: 水面はどんな風ですか？
#            正解      : 穏やか
#            生成回答  : 水面は霧で覆われていて、ぼやけています。
#
# [Image 17 | QA 5] 質問: 地面はどんな風ですか？
#            正解      : 砂浜が広がっている
#            生成回答  : 地面は、砂浜で、全体的に薄いベージュ色です。
#
# [Image 17 | QA 6] 質問: 何人いますか？
#            正解      : １人
#            生成回答  : 2人です。
#
# [Image 17 | QA 7] 質問: 犬は何匹いますか？
#            正解      : １匹
#            生成回答  : 犬は1匹です。
#
#
# ====== [VQA] Image 18 の質問処理 ======
# [Image 18 | QA 0] 質問: 画像に写っているのはどこですか？
#            正解      : 店内
#            生成回答  : 画像に写っているのは、スーパーマーケットの野菜売り場の前で、ニンジンを手に笑顔でポーズをとっている女性です。背景には、様々な野菜が並んでいます。
#
# [Image 18 | QA 1] 質問: 画像に最も大きく写っているのは誰ですか？
#            正解      : 女性
#            生成回答  : 女性です。
#
# [Image 18 | QA 2] 質問: 画像に写っている人の数はいくつですか？
#            正解      : ２
#            生成回答  : 画像に写っている人は2人です。
#
# [Image 18 | QA 3] 質問: 画像に写っている女性が手に持っているにんじんの数はいくつですか？
#            正解      : １
#            生成回答  : にんじんは5本です。
#
# [Image 18 | QA 4] 質問: 画像に最も大きく写っている女性はどんな状態ですか？
#            正解      : 人参を持っている
#            生成回答  : 女性は笑顔で、長いニンジンを手に持っています。
#
# [Image 18 | QA 5] 質問: 画像に最も大きく写っている女性はどんな格好ですか？
#            正解      : ダウンジャケットを着ている
#            生成回答  : 白いダウンジャケットとスカーフを着ています。
#
# [Image 18 | QA 6] 質問: 画像に写っている最も大きく写っている女性のジャケットの色は何色ですか？
#            正解      : 白と黒
#            生成回答  : 白いです。
#
# [Image 18 | QA 7] 質問: 画像に写っている最も大きく写っている女性のジャケットのファスナーの色は何色ですか？
#            正解      : 銀色
#            生成回答  : 白です。
#
#
# ====== [VQA] Image 19 の質問処理 ======
# [Image 19 | QA 0] 質問: どんな天気ですか？
#            正解      : 晴れです。
#            生成回答  : 晴れです。
#
# [Image 19 | QA 1] 質問: 空の色は何ですか？
#            正解      : 青です。
#            生成回答  : 青色です。
#
# [Image 19 | QA 2] 質問: 左の建物の外壁の色は何ですか？
#            正解      : 茶色です。
#            生成回答  : 茶色です。
#
# [Image 19 | QA 3] 質問: 電話の看板の色は何ですか？
#            正解      : 青です。
#            生成回答  : 赤いです。
#
# [Image 19 | QA 4] 質問: 電話の絵の看板はいくつありますか？
#            正解      : 2枚です。
#            生成回答  : 2つ
#
# [Image 19 | QA 5] 質問: 左の飲食店の営業時間はどれくらいですか？
#            正解      : 24時間です。
#            生成回答  : 24時間営業です。
#
# [Image 19 | QA 6] 質問: 左の飲食店の屋上に立っている看板の支柱の色は何ですか？
#            正解      : 赤です。
#            生成回答  : 赤色です。
#
# [Image 19 | QA 7] 質問: 左のフェンスに付いている葉の色は何ですか？
#            正解      : 緑です。
#            生成回答  : 緑色です。
#
#
# ====== [VQA] Image 20 の質問処理 ======
# [Image 20 | QA 0] 質問: ここはどこですか？
#            正解      : とある市街地の道路の一角です。
#            生成回答  : これは、イギリスのマンチェスターにある、広大な道路です。
#
# [Image 20 | QA 1] 質問: この場所の天気はどうですか？
#            正解      : 曇り空です。
#            生成回答  : 曇り
#
# [Image 20 | QA 2] 質問: この道路にはどんな特徴がありますか？
#            正解      : 片側１車線の舗装道路です。
#            生成回答  : 道路は、高層ビルが立ち並ぶ都市部の道路で、黄色い路線の線引きと、道路の脇に沿って石畳の歩道があります。
#
# [Image 20 | QA 3] 質問: 道路上はどんな様子ですか？
#            正解      : バスが２台走っています。
#            生成回答  : 道路は舗装されており、黄色い線で区切られています。背景には高層ビルが立ち並び、バスが走っています。
#
# [Image 20 | QA 4] 質問: 正面のバスにはどんな特徴がありますか？
#            正解      : 側面に広告が掲示された２階建てバスです。
#            生成回答  : 正面のバスは、青と白のカラフルなデザインで、2段構造のデッカーバスです。広告が掲載されています。
#
# [Image 20 | QA 5] 質問: 左奥側のバスの車体は何色ですか？
#            正解      : シルバーです。
#            生成回答  : 青と白です。
#
# [Image 20 | QA 6] 質問: 歩行者は何人いますか？
#            正解      : 誰もおらず、ゼロ人です。
#            生成回答  : 歩行者はいません。
#
# [Image 20 | QA 7] 質問: 道路の向こう側には何が見えますか？
#            正解      : 高層ビルが数棟建てられています。
#            生成回答  : 道路の向こう側には、高層ビルと、橋の向こうに建物の群れが見えます。
#
#
# ====== [VQA] Image 21 の質問処理 ======
# [Image 21 | QA 0] 質問: これは何ですか？
#            正解      : 鳥です。
#            生成回答  : これは、水辺にいるハシビロガメです。
#
# [Image 21 | QA 1] 質問: 鳥は何羽いますか？
#            正解      : １羽です。
#            生成回答  : 1羽です。
#
# [Image 21 | QA 2] 質問: どんな場所ですか？
#            正解      : 植物が茂った水辺です。
#            生成回答  : 公園の池のそばの緑の芝生に囲まれた場所です。
#
# [Image 21 | QA 3] 質問: 水はどんな色をしていますか？
#            正解      : 緑色に濁っています。
#            生成回答  : 水は緑色をしています。
#
# [Image 21 | QA 4] 質問: 水辺の対岸はどうなっていますか？
#            正解      : 芝生があって、奥には木が茂っています。
#            生成回答  : 水辺の対岸には、緑の芝生、植物、そして水路があります。
#
# [Image 21 | QA 5] 質問: 鳥は何をしていますか？
#            正解      : 水面の上を羽根を広げて飛んでいます。
#            生成回答  : 鳥は水辺に飛び降り、魚を捕まえています。
#
# [Image 21 | QA 6] 質問: 鳥の足はどこを向いていますか？
#            正解      : 下を向いています。
#            生成回答  : 鳥の足は、水面に向いています。
#
# [Image 21 | QA 7] 質問: どんな天気ですか？
#            正解      : 晴れています。
#            生成回答  : 晴れです。
#
#
# ====== [VQA] Image 22 の質問処理 ======
# [Image 22 | QA 0] 質問: トラックは何台ありますか？
#            正解      : 1台
#            生成回答  : トラックは1台あります。
#
# [Image 22 | QA 1] 質問: ごみ箱は何個ありますか？
#            正解      : 1個
#            生成回答  : 3個
#
# [Image 22 | QA 2] 質問: 四角い信号は何機ありますか？
#            正解      : 1機
#            生成回答  : 10機
#
# [Image 22 | QA 3] 質問: 黒いシャツを着た人は何人いますか？
#            正解      : 3人
#            生成回答  : 1人です。
#
# [Image 22 | QA 4] 質問: 信号機に登っている人は何人いますか？
#            正解      : 1人
#            生成回答  : わからない
#
# [Image 22 | QA 5] 質問: ごみ箱はどんな色ですか？
#            正解      : 黒
#            生成回答  : 黒色です。
#
# [Image 22 | QA 6] 質問: 矢印の描かれた標識はいくつありますか？
#            正解      : 1つ
#            生成回答  : 2つ
#
# [Image 22 | QA 7] 質問: 信号機はどんな色のランプがついていますか？
#            正解      : 赤
#            生成回答  : 赤、黄、緑のランプがついています。
#
#
# ====== [VQA] Image 23 の質問処理 ======
# [Image 23 | QA 0] 質問: どこで撮られた画像ですか?
#            正解      : 雪道
#            生成回答  : ノルウェーの山岳地帯で撮影されました。
#
# [Image 23 | QA 1] 質問: 誰を撮った画像ですか?
#            正解      : 男性、女性
#            生成回答  : この画像は、スキーをしているグループの自撮りです。
#
# [Image 23 | QA 2] 質問: 何人の人物を撮った画像ですか?
#            正解      : 5人
#            生成回答  : 6人
#
# [Image 23 | QA 3] 質問: 1番近くで写っている人は誰ですか?
#            正解      : 男性
#            生成回答  : 写真の最も近くで写っている人は、左端の男性です。
#
# [Image 23 | QA 4] 質問: 1番近くで写っている男性は何色のゴーグルをかけていますか?
#            正解      : シルバー、オレンジ、黒
#            生成回答  : 赤色です。
#
# [Image 23 | QA 5] 質問: 1番近くで写っている男性は何色のウェアを着ていますか?
#            正解      : 赤、青
#            生成回答  : 赤色です。
#
# [Image 23 | QA 6] 質問: 1番近くで写っている男性の近くで写っている物は何ですか?
#            正解      : 乗用車
#            生成回答  : サングラスです。
#
# [Image 23 | QA 7] 質問: 乗用車の色は何色ですか?
#            正解      : 赤
#            生成回答  : 赤色です。
#
#
# ====== [VQA] Image 24 の質問処理 ======
# [Image 24 | QA 0] 質問: 写真に写っているものは何ですか
#            正解      : 汽車
#            生成回答  : 蒸気機関車です。
#
# [Image 24 | QA 1] 質問: どんな色ですか
#            正解      : 緑
#            生成回答  : 緑色です。
#
# [Image 24 | QA 2] 質問: どこを走っていますか
#            正解      : 線路の上
#            生成回答  : この蒸気機関車は、線路を走っています。
#
# [Image 24 | QA 3] 質問: 線路はどれくらい写っていますか
#            正解      : ３本
#            生成回答  : 線路が大部分写っています。
#
# [Image 24 | QA 4] 質問: 人は何人いますか
#            正解      : いません
#            生成回答  : 画像には人が写っていません。
#
# [Image 24 | QA 5] 質問: 線路の向こうにあるものは何ですか
#            正解      : 樹木
#            生成回答  : 線路の向こうには緑豊かな木々があります。
#
# [Image 24 | QA 6] 質問: 車輪はいくつありますか
#            正解      : ７個
#            生成回答  : 4
#
# [Image 24 | QA 7] 質問: 乗り物の先頭は何色ですか
#            正解      : 黒
#            生成回答  : 緑色です。
#
#
# ====== [VQA] Image 25 の質問処理 ======
# [Image 25 | QA 0] 質問: ここはどこですか？
#            正解      : テニスコート
#            生成回答  : ここはテニスコートです。
#
# [Image 25 | QA 1] 質問: 誰かいますか？
#            正解      : 男性がいる
#            生成回答  : 画像にはテニスをしている2人の男性が写っています。
#
# [Image 25 | QA 2] 質問: 男性は何人いますか？
#            正解      : ２人
#            生成回答  : 2人です。
#
# [Image 25 | QA 3] 質問: 男性たちは何をしていますか？
#            正解      : テニス
#            生成回答  : 男性たちはテニスをしています。
#
# [Image 25 | QA 4] 質問: 手前の男性のウェアは何色ですか？
#            正解      : 茶色
#            生成回答  : 茶色と白です。
#
# [Image 25 | QA 5] 質問: 手前の男性のラケットは何色ですか？
#            正解      : 黄色
#            生成回答  : 黄色です。
#
# [Image 25 | QA 6] 質問: テニスコートはどんなサーフェイスですか？
#            正解      : アンツーカー
#            生成回答  : テニスコートは、赤茶色の土の表面のコートです。
#
# [Image 25 | QA 7] 質問: 天気はどうですか？
#            正解      : 曇り
#            生成回答  : 晴れです。
#
#
# ====== [VQA] Image 26 の質問処理 ======
# [Image 26 | QA 0] 質問: 屋外と屋内のうち、どこで撮られたものですか？
#            正解      : 屋内
#            生成回答  : 屋内で撮影されました。
#
# [Image 26 | QA 1] 質問: 壁はどんな色ですか？
#            正解      : ベージュ
#            生成回答  : 壁はクリーム色です。
#
# [Image 26 | QA 2] 質問: ベッドはいくつありますか？
#            正解      : 2
#            生成回答  : 2つ
#
# [Image 26 | QA 3] 質問: 枕はどんな色ですか？
#            正解      : 白
#            生成回答  : 枕は白です。
#
# [Image 26 | QA 4] 質問: ベッドカバーはどんな色ですか？
#            正解      : 黄
#            生成回答  : ベッドカバーは、金色の模様が入ったオレンジ色です。
#
# [Image 26 | QA 5] 質問: 電気スタンドはいくつありますか？
#            正解      : 2
#            生成回答  : 2つ
#
# [Image 26 | QA 6] 質問: サイドテーブルはいくつありますか？
#            正解      : 1
#            生成回答  : 2つ
#
# [Image 26 | QA 7] 質問: 飾られている絵はいくつありますか？
#            正解      : 2
#            生成回答  : 3つ
#
#
# ====== [VQA] Image 27 の質問処理 ======
# [Image 27 | QA 0] 質問: 何色の果物が実っていますか？
#            正解      : 黄色
#            生成回答  : オレンジです。
#
# [Image 27 | QA 1] 質問: 天気はどうですか？
#            正解      : 晴れ
#            生成回答  : 晴れです。
#
# [Image 27 | QA 2] 質問: 木の幹は何色ですか？
#            正解      : 白色
#            生成回答  : 白いです。
#
# [Image 27 | QA 3] 質問: 崖への転落防止の柵は何色ですか？
#            正解      : 白色
#            生成回答  : 白い柵です。
#
# [Image 27 | QA 4] 質問: 木々の左側にある白色の棒はなぜ設置されていますか？
#            正解      : 転落防止の為
#            生成回答  : これらの棒は、果樹園で、果実が落ちるのを防ぐために設置されています。
#
# [Image 27 | QA 5] 質問: 実っている果物は何系の果物に分類されますか？
#            正解      : 柑橘系
#            生成回答  : オレンジです。
#
# [Image 27 | QA 6] 質問: 写真のピントはどこに一番合っていますか？
#            正解      : 左上隅から少し中ほど
#            生成回答  : ピントはオレンジの果実に一番合っています。
#
# [Image 27 | QA 7] 質問: 写真の果物は何ですか？
#            正解      : オレンジ
#            生成回答  : オレンジです。
#
#
# ====== [VQA] Image 28 の質問処理 ======
# [Image 28 | QA 0] 質問: 何がありますか？
#            正解      : 空港があります。
#            生成回答  : 港湾施設、コンテナ、クレーン、貨物船があります。
#
# [Image 28 | QA 1] 質問: どこから空港を見ていますか？
#            正解      : 空の上からです。
#            生成回答  : 空港の窓から撮影されたものです。
#
# [Image 28 | QA 2] 質問: 何に乗っていますか？
#            正解      : 飛行機です。
#            生成回答  : 貨物船
#
# [Image 28 | QA 3] 質問: 飛行機のどこの席ですか？
#            正解      : コックピットです。
#            生成回答  : 左側の窓から見えています。
#
# [Image 28 | QA 4] 質問: コックピットは、どんな状態になっていますか？
#            正解      : 斜めになっています。
#            生成回答  : コックピットは、飛行機の窓から見えています。
#
# [Image 28 | QA 5] 質問: なぜ、コックピットは、斜めになっていますか？
#            正解      : 着陸するからです。
#            生成回答  : コックピットが斜めになっているのは、飛行機が上昇または下降しているためです。
#
# [Image 28 | QA 6] 質問: 空港には、何がありますか？
#            正解      : 滑走路があります。
#            生成回答  : この画像は、港の空撮写真です。コンテナ船やクレーン、トラックなどが、港湾施設に集まっている様子が分かります。
#
# [Image 28 | QA 7] 質問: 空港の横には、何がありますか？
#            正解      : 工事で埋め立てている土地があります。
#            生成回答  : 港
#
#
# ====== [VQA] Image 29 の質問処理 ======
# [Image 29 | QA 0] 質問: 女性はどんなスポーツをしていますか
#            正解      : テニス
#            生成回答  : 女性はテニスをしています。
#
# [Image 29 | QA 1] 質問: 誰がテニスをしていますか
#            正解      : 女性
#            生成回答  : この画像には、テニスをしている女性が写っています。
#
# [Image 29 | QA 2] 質問: 女性は手にラケットをいくつ持っていますか
#            正解      : 1つ
#            生成回答  : 女性は手にラケットを1本持っています。
#
# [Image 29 | QA 3] 質問: 女性の足元はどんな地面ですか
#            正解      : 土
#            生成回答  : 赤い土のテニスコートです。
#
# [Image 29 | QA 4] 質問: 屋内と屋外のどこにいますか
#            正解      : 屋外
#            生成回答  : 屋外です。
#
# [Image 29 | QA 5] 質問: 女性は頭に何をかぶっていますか
#            正解      : サンバイザー
#            生成回答  : 女性は白のバイザーをかぶっています。
#
# [Image 29 | QA 6] 質問: 女性は足に何をつけていますか
#            正解      : サポーター
#            生成回答  : 女性は、足に赤い靴を履いています。
#
# [Image 29 | QA 7] 質問: 女性は足に何を履いていますか
#            正解      : スニーカー
#            生成回答  : 赤いスニーカーを履いています。
#
#
# ====== [VQA] Image 30 の質問処理 ======
# [Image 30 | QA 0] 質問: 誰か人はいますか
#            正解      : います
#            生成回答  : はい、人がいます。
#
# [Image 30 | QA 1] 質問: 何人の人がいますか
#            正解      : 一人
#            生成回答  : 5人
#
# [Image 30 | QA 2] 質問: どこに人はいますか
#            正解      : 海
#            生成回答  : 画像には、サーフィンをしている男性がいます。
#
# [Image 30 | QA 3] 質問: 人はどんな性別ですか
#            正解      : 男性
#            生成回答  : 男性です。
#
# [Image 30 | QA 4] 質問: 人は何をしてますか
#            正解      : サーフィン
#            生成回答  : サーフィンをしている男性です。
#
# [Image 30 | QA 5] 質問: なぜそう思うんですか
#            正解      : サーフボードで波に乗っている
#            生成回答  : この画像は、男性が波に乗っている様子を捉えています。彼は波に乗って楽しんでいるように見えます。
#
# [Image 30 | QA 6] 質問: サーフボードの色は何色ですか
#            正解      : 白
#            生成回答  : 黒と茶色です。
#
# [Image 30 | QA 7] 質問: 男性はどんな格好ですか
#            正解      : Tシャツに半ズボン
#            生成回答  : 彼は、Tシャツとショートパンツを着ています。
#
#
# ====== [VQA] Image 31 の質問処理 ======
# [Image 31 | QA 0] 質問: 器は全部でいくつありますか？
#            正解      : ４つ
#            生成回答  : 4つ
#
# [Image 31 | QA 1] 質問: 丸い形の器は全部でいくつありますか？
#            正解      : ４つ
#            生成回答  : 丸い形の器は全部で4つあります。
#
# [Image 31 | QA 2] 質問: 器に入ってない果物は何ですか？
#            正解      : バナナ
#            生成回答  : バナナです。
#
# [Image 31 | QA 3] 質問: バナナは全部でいくつありますか？
#            正解      : １本
#            生成回答  : バナナは1つです。
#
# [Image 31 | QA 4] 質問: 右手前の器に入っているのはどんな野菜ですか？
#            正解      : ブロッコリー
#            生成回答  : レンズ豆です。
#
# [Image 31 | QA 5] 質問: 左手前の器に入っているのはどんな野菜ですか？
#            正解      : 人参
#            生成回答  : レンズ豆です。
#
# [Image 31 | QA 6] 質問: 右手前の器に入っている野菜はどんな色ですか？
#            正解      : 緑色
#            生成回答  : 赤色です。
#
# [Image 31 | QA 7] 質問: 左手前の器に入っている野菜はどんな色ですか？
#            正解      : オレンジ色
#            生成回答  : 赤色です。
#
#
# ====== [VQA] Image 32 の質問処理 ======
# [Image 32 | QA 0] 質問: 室内ですか室外ですか
#            正解      : 室外
#            生成回答  : 室外です。
#
# [Image 32 | QA 1] 質問: 天候は
#            正解      : 晴れ
#            生成回答  : 晴れ
#
# [Image 32 | QA 2] 質問: 何が写っていますか
#            正解      : 建物
#            生成回答  : パリの路地に、赤い自転車が置かれています。背景には建物や自転車が並んでいます。
#
# [Image 32 | QA 3] 質問: 何が写っていますか
#            正解      : 舗道
#            生成回答  : パリの路地に、赤い自転車が置かれています。背景には建物や自転車が並んでいます。
#
# [Image 32 | QA 4] 質問: 何が写っていますか
#            正解      : 横断歩道
#            生成回答  : パリの路地に、赤い自転車が置かれています。背景には建物や自転車が並んでいます。
#
# [Image 32 | QA 5] 質問: 何が写っていますか
#            正解      : 自転車
#            生成回答  : パリの路地に、赤い自転車が置かれています。背景には建物や自転車が並んでいます。
#
# [Image 32 | QA 6] 質問: 何が写っていますか
#            正解      : ダストボックス
#            生成回答  : パリの路地に、赤い自転車が置かれています。背景には建物や自転車が並んでいます。
#
# [Image 32 | QA 7] 質問: 人は写っていますか
#            正解      : 写っていない
#            生成回答  : はい、写っています。
#
#
# ====== [VQA] Image 33 の質問処理 ======
# [Image 33 | QA 0] 質問: 天気はどうですか？
#            正解      : 晴れ
#            生成回答  : 晴れです。
#
# [Image 33 | QA 1] 質問: 場所はどこですか？
#            正解      : 海
#            生成回答  : この画像は、カリフォルニア州のサンディエゴにあるラホヤビーチで撮影されたものです。
#
# [Image 33 | QA 2] 質問: 人は何人いますか？
#            正解      : 1人
#            生成回答  : それ以上
#
# [Image 33 | QA 3] 質問: 誰がいますか？
#            正解      : 男性
#            生成回答  : 画像にはサーフィンをしている男性がいます。
#
# [Image 33 | QA 4] 質問: 男性が着ている服の種類は何ですか？
#            正解      : ウェットスーツ
#            生成回答  : 黒いウェットスーツを着ています。
#
# [Image 33 | QA 5] 質問: 男性が着ているウェットスーツの色は何色ですか？
#            正解      : 黒色
#            生成回答  : 黒色です。
#
# [Image 33 | QA 6] 質問: 男性の髪の色は何色ですか？
#            正解      : 黒色
#            生成回答  : 黒色です。
#
# [Image 33 | QA 7] 質問: 男性は何のスポーツをしていますか？
#            正解      : サーフィン
#            生成回答  : サーフィン
#
#
# ====== [VQA] Image 34 の質問処理 ======
# [Image 34 | QA 0] 質問: 宙に浮いている男性は足に何をつけていますか
#            正解      : スキー板
#            生成回答  : 彼は、スノーボードを履いています。
#
# [Image 34 | QA 1] 質問: 宙に浮いている男性はどんな色のシャツを着ていますか
#            正解      : 紫色
#            生成回答  : 紫色のシャツを着ています。
#
# [Image 34 | QA 2] 質問: 宙に浮いている男性はどんな色のズボンをはいていますか
#            正解      : 緑色
#            生成回答  : 緑色のズボンをはいています。
#
# [Image 34 | QA 3] 質問: 地上に人はどれくらいいますか
#            正解      : 多数
#            生成回答  : 約30人です。
#
# [Image 34 | QA 4] 質問: 奥のほうには何が停まっていますか
#            正解      : 自動車
#            生成回答  : 奥のほうには車が停まっています。
#
# [Image 34 | QA 5] 質問: 奥の右側にあるテントはどんな色ですか
#            正解      : 黄色
#            生成回答  : 青と白です。
#
# [Image 34 | QA 6] 質問: 宙に浮いている男性は頭に何をかぶっていますか
#            正解      : ヘルメット
#            生成回答  : ヘルメットをかぶっています。
#
# [Image 34 | QA 7] 質問: 宙に浮いている男性のかぶっているものはどんな色ですか
#            正解      : 黒色
#            生成回答  : 黒色です。
#
#
# ====== [VQA] Image 35 の質問処理 ======
# [Image 35 | QA 0] 質問: 台は何色ですか
#            正解      : 銀色
#            生成回答  : 黒と白です。
#
# [Image 35 | QA 1] 質問: 天気はどうですか
#            正解      : 晴れている
#            生成回答  : 晴れです。
#
# [Image 35 | QA 2] 質問: 誰がいますか
#            正解      : 誰もいない
#            生成回答  : ピザです。
#
# [Image 35 | QA 3] 質問: 台には皿が何枚乗っていますか
#            正解      : １枚
#            生成回答  : 3枚
#
# [Image 35 | QA 4] 質問: 皿は何色ですか
#            正解      : 白
#            生成回答  : 白です。
#
# [Image 35 | QA 5] 質問: 皿の上に乗っている食べ物は何ですか
#            正解      : ピザ
#            生成回答  : ピザです。
#
# [Image 35 | QA 6] 質問: ピザはどんな形ですか
#            正解      : 丸い
#            生成回答  : 円形です。
#
# [Image 35 | QA 7] 質問: 皿の右側には何色の物が置いてありますか
#            正解      : 白
#            生成回答  : 黒色のボトルです。
#
#
# ====== [VQA] Image 36 の質問処理 ======
# [Image 36 | QA 0] 質問: 皿の色は何ですか？
#            正解      : 白
#            生成回答  : 白い皿に、アスパラガス、ベーコン、ハッシュドポテト、ポーチドエッグ、そしてソースが乗っています。
#
# [Image 36 | QA 1] 質問: どんな机の模様ですか？
#            正解      : 木目調
#            生成回答  : 机の模様は、木目調の明るい茶色です。
#
# [Image 36 | QA 2] 質問: クリップの数はいくつですか？
#            正解      : ふたつ
#            生成回答  : 3つ
#
# [Image 36 | QA 3] 質問: ナイフは何本ですか？
#            正解      : 1本
#            生成回答  : 2本
#
# [Image 36 | QA 4] 質問: ナイフの色は何ですか？
#            正解      : 黒
#            生成回答  : 黒色です。
#
# [Image 36 | QA 5] 質問: アスパラガスが入った食べ物の数はいくつですか？
#            正解      : ふたつ
#            生成回答  : 3
#
# [Image 36 | QA 6] 質問: フォークはいくつありますか？
#            正解      : 1本
#            生成回答  : 2本
#
# [Image 36 | QA 7] 質問: クリームの色は何ですか？
#            正解      : 黄色
#            生成回答  : 黄色です。
#
#
# ====== [VQA] Image 37 の質問処理 ======
# [Image 37 | QA 0] 質問: 左側に積まれている物は何ですか？
#            正解      : トマト
#            生成回答  : 赤いトマトが大量に積まれています。
#
# [Image 37 | QA 1] 質問: 左側にあるトマトは何色ですか？
#            正解      : 赤色
#            生成回答  : 赤色です。
#
# [Image 37 | QA 2] 質問: 左側にあるトマトはどんな形状ですか？
#            正解      : 丸
#            生成回答  : 丸いトマトがいくつかあります。
#
# [Image 37 | QA 3] 質問: 左側にあるトマトは何に積まれていますか？
#            正解      : ダンボール
#            生成回答  : トマトは袋に入った状態で積まれています。
#
# [Image 37 | QA 4] 質問: トマトが積まれているダンボールは何色ですか？
#            正解      : 茶色
#            生成回答  : 赤色です。
#
# [Image 37 | QA 5] 質問: ダンボールを載せている台は何色ですか？
#            正解      : 水色
#            生成回答  : 青色です。
#
# [Image 37 | QA 6] 質問: ダンボールを載せている台はいくつですか？
#            正解      : 1台
#            生成回答  : 3つ
#
# [Image 37 | QA 7] 質問: 奥にある大きな食べ物は何ですか？
#            正解      : 南瓜
#            生成回答  : 奥にある大きな食べ物はスイカです。
#
#
# ====== [VQA] Image 38 の質問処理 ======
# [Image 38 | QA 0] 質問: 人は何人写っていますか？
#            正解      : 1人
#            生成回答  : 5人
#
# [Image 38 | QA 1] 質問: 人以外にどんな動物が写っていますか？
#            正解      : 犬
#            生成回答  : チワワ
#
# [Image 38 | QA 2] 質問: 犬はどんなものの中から顔を出していますか？
#            正解      : キャリーバック
#            生成回答  : 犬は赤い旅行用スーツケースの中から顔を出しています。
#
# [Image 38 | QA 3] 質問: 犬は何匹写っていますか？
#            正解      : 1匹
#            生成回答  : それ以上
#
# [Image 38 | QA 4] 質問: キャリーバックはいくつうつっていますか？
#            正解      : １つ
#            生成回答  : 1
#
# [Image 38 | QA 5] 質問: うつっているキャリーバックは黒色と何色で構成されていますか？
#            正解      : 赤色
#            生成回答  : 黒色と赤色です。
#
# [Image 38 | QA 6] 質問: うつっている人は何色の靴を履いていますか？
#            正解      : 黒色
#            生成回答  : 黒色の靴を履いています。
#
# [Image 38 | QA 7] 質問: 犬の頭頂部は何色の毛ですか？
#            正解      : 黒色
#            生成回答  : 茶色と黒です。
#
#
# ====== [VQA] Image 39 の質問処理 ======
# [Image 39 | QA 0] 質問: 動物は何頭見えますか？
#            正解      : 1
#            生成回答  : 3頭です。
#
# [Image 39 | QA 1] 質問: 動物は何がいますか？
#            正解      : 象
#            生成回答  : アフリカの湿地帯にいる象です。
#
# [Image 39 | QA 2] 質問: 象はどこにいますか？
#            正解      : 水の中
#            生成回答  : 象は水の中にいます。
#
# [Image 39 | QA 3] 質問: 象は何をしていますか？
#            正解      : 水の中に入っている
#            生成回答  : 象は水中で浮いているようです。
#
# [Image 39 | QA 4] 質問: 象の目はいくつ見えますか？
#            正解      : 1
#            生成回答  : 象の目は4つ見えます。
#
# [Image 39 | QA 5] 質問: 象の耳はいくつ見えますか？
#            正解      : 1
#            生成回答  : 象の耳は2つ見えます。
#
# [Image 39 | QA 6] 質問: 象の鼻はいくつ見えますか？
#            正解      : 1
#            生成回答  : 象の鼻は2つ見えます。
#
# [Image 39 | QA 7] 質問: 手前にある紐は何色ですか？
#            正解      : 緑
#            生成回答  : 緑色です。
#
#
# ====== [VQA] Image 40 の質問処理 ======
# [Image 40 | QA 0] 質問: ここはどこですか？
#            正解      : 屋外の建物前です。
#            生成回答  : これは、動物園やサファリパークの動物舎の背景です。
#
# [Image 40 | QA 1] 質問: いつ撮られたものですか？
#            正解      : 日中です。
#            生成回答  : 2023年10月27日
#
# [Image 40 | QA 2] 質問: 天気はどんなお天気ですか？
#            正解      : 晴れです。
#            生成回答  : 晴れです。
#
# [Image 40 | QA 3] 質問: 誰か人は見えますか？
#            正解      : 誰も見当たりません。
#            生成回答  : いいえ、見えません。
#
# [Image 40 | QA 4] 質問: 動物は何がいますか？
#            正解      : シマウマがいます。
#            生成回答  : この画像には、背中に縞模様のあるゼブラがいます。
#
# [Image 40 | QA 5] 質問: 動物は幾頭いますか？
#            正解      : 2頭います。
#            生成回答  : わからない
#
# [Image 40 | QA 6] 質問: 動物と建物の間に何がありますか?
#            正解      : フェンスがあります。
#            生成回答  : ズーラトリウムの柵に囲まれたゼブラの尻尾です。
#
# [Image 40 | QA 7] 質問: 建物の壁はどんな色合いですか？
#            正解      : ライトグリーンです。
#            生成回答  : 緑色です。
#
#
# ====== [VQA] Image 41 の質問処理 ======
# [Image 41 | QA 0] 質問: どんな乗り物がありますか？
#            正解      : 電車
#            生成回答  : この画像には、雪が降っている中を走る鉄道車両（電車）があります。
#
# [Image 41 | QA 1] 質問: 電車はどこに停まっていますか？
#            正解      : 駅のホーム
#            生成回答  : 電車は駅に停まっています。
#
# [Image 41 | QA 2] 質問: 駅のホームに誰かいますか？
#            正解      : 誰もいません。
#            生成回答  : はい、駅のホームに人がいます。
#
# [Image 41 | QA 3] 質問: 先頭車両の正面にライトはいくつありますか？
#            正解      : 六個
#            生成回答  : 3つ
#
# [Image 41 | QA 4] 質問: 先頭車両の正面のドアはどんな形ですか？
#            正解      : 長方形
#            生成回答  : 先頭車両の正面のドアは、長方形で、窓のすぐ上にあります。
#
# [Image 41 | QA 5] 質問: 先頭車両の正面のドア枠は何色ですか？
#            正解      : 黒色
#            生成回答  : 黄色と赤です。
#
# [Image 41 | QA 6] 質問: 天気はどうですか？
#            正解      : 雪が降っています。
#            生成回答  : 雨が降っています。
#
# [Image 41 | QA 7] 質問: 手前のホームの上はどうなっていますか？
#            正解      : 雪が積もっています。
#            生成回答  : 手前のホームの上には、ガラス張りの建物があります。
#
#
# ====== [VQA] Image 42 の質問処理 ======
# [Image 42 | QA 0] 質問: 天気は何ですか
#            正解      : 晴れです
#            生成回答  : 晴れです。
#
# [Image 42 | QA 1] 質問: 時間帯はいつですか
#            正解      : 日中です
#            生成回答  : 夕方です。
#
# [Image 42 | QA 2] 質問: 場所はどこですか
#            正解      : 野球場です
#            生成回答  : テキサス大学の野球場です。
#
# [Image 42 | QA 3] 質問: 人は何人いますか
#            正解      : ３人です
#            生成回答  : 5人です。
#
# [Image 42 | QA 4] 質問: ３人はどんな格好ですか
#            正解      : 野球のユニフォーム姿です
#            生成回答  : （彼らは野球のユニフォームを着ています。）
#
# [Image 42 | QA 5] 質問: ピッチャーの背番号は何番ですか
#            正解      : ３１番です
#            生成回答  : ピッチャーの背番号は31番です。
#
# [Image 42 | QA 6] 質問: ３人の性別は何ですか
#            正解      : ３人は男性です
#            生成回答  : ３人は男性です。
#
# [Image 42 | QA 7] 質問: ショートの背番号は何番ですか
#            正解      : ９番です
#            生成回答  : 背番号9です。
#
#
# ====== [VQA] Image 43 の質問処理 ======
# [Image 43 | QA 0] 質問: ガラスケースの中には何がありますか？
#            正解      : スマートフォン
#            生成回答  : ガラスケースの中には、iPhoneとPradaの携帯電話があります。
#
# [Image 43 | QA 1] 質問: ガラスケースの上にはスマートフォンがいくつありますか？
#            正解      : 2つ
#            生成回答  : 4つ
#
# [Image 43 | QA 2] 質問: ガラスケースの上にあるスマートフォンは何色ですか？
#            正解      : 黒色
#            生成回答  : 黒色です。
#
# [Image 43 | QA 3] 質問: ガラスケースの底面には何色のシートが敷かれていますか？
#            正解      : 水色
#            生成回答  : 青色です。
#
# [Image 43 | QA 4] 質問: ガラスケースの底面にあるシートにプリントされた文字は何色ですか？
#            正解      : 白色
#            生成回答  : 黒色です。
#
# [Image 43 | QA 5] 質問: ガラスケースの中にあるものはどんなふうに置かれていますか？
#            正解      : 各々がスタンドに立てて並べられている
#            生成回答  : ガラスケースの中には、黒いスマートフォンが2台並んでいます。1台はシンプルなデザインで、もう1台はPradaのロゴが刻印された高級感のあるデザインです。
#
# [Image 43 | QA 6] 質問: 人の手は何を持っていますか？
#            正解      : スマートフォンのストラップ
#            生成回答  : ペン
#
# [Image 43 | QA 7] 質問: スマートフォンのストラップはどんな形状ですか？
#            正解      : 細長い円筒形
#            生成回答  : スマートフォンのストラップは、黒い金属製のループ状のものです。
#
#
# ====== [VQA] Image 44 の質問処理 ======
# [Image 44 | QA 0] 質問: 何の画像ですか？
#            正解      : オートバイの画像です。
#            生成回答  : これは、荷物でいっぱいになった銀色のホンダCB400バイクの写真です。
#
# [Image 44 | QA 1] 質問: どんな乗り物の画像ですか？
#            正解      : オートバイの画像です。
#            生成回答  : これは、荷物でいっぱいになった銀色のホンダのバイクです。
#
# [Image 44 | QA 2] 質問: オートバイは、何台写っていますか？
#            正解      : 一台だけ写っています。
#            生成回答  : 1台のオートバイです。
#
# [Image 44 | QA 3] 質問: オートバイのメーカーは、どこですか？
#            正解      : HONDAです。
#            生成回答  : Hondaです。
#
# [Image 44 | QA 4] 質問: 誰がオートバイに乗っていますか？
#            正解      : 誰も乗っていません。
#            生成回答  : この画像には、オートバイに乗っている人物は写っていません。オートバイだけが写っています。
#
# [Image 44 | QA 5] 質問: 青い鞄は、どこに乗せられていますか？
#            正解      : 荷台に乗せられています。
#            生成回答  : 青い鞄は、バイクのパニアケースに積まれています。
#
# [Image 44 | QA 6] 質問: 荷台の荷物は、どうなっていますか？
#            正解      : 赤い紐で縛られています。
#            生成回答  : 荷物は、いくつかのバックパックと、おそらく箱やバッグが積み重ねられています。
#
# [Image 44 | QA 7] 質問: オートバイのどこから撮影した画像ですか？
#            正解      : オートバイの横から撮影した画像です。
#            生成回答  : この画像は、銀色のHonda GL1000のバイクです。バイクには、たくさんの荷物が積まれています。
#
#
# ====== [VQA] Image 45 の質問処理 ======
# [Image 45 | QA 0] 質問: どんな天気ですか？
#            正解      : 晴れ
#            生成回答  : 晴れです。
#
# [Image 45 | QA 1] 質問: 道路に置かれている袋の色は何ですか？
#            正解      : 青
#            生成回答  : この画像について「道路に置かれている袋の色は何ですか？」という質問に対して、簡潔に日本語で答えてください。青です。
#
# [Image 45 | QA 2] 質問: お店はいくつありますか？
#            正解      : 2つ
#            生成回答  : 3つ
#
# [Image 45 | QA 3] 質問: 街灯はいくつありますか？
#            正解      : 1つ
#            生成回答  : 3つ
#
# [Image 45 | QA 4] 質問: 自動車はいくつありますか？
#            正解      : 0台
#            生成回答  : 画像には自動車は1台しかありません。
#
# [Image 45 | QA 5] 質問: ベビーカーはいくつありますか？
#            正解      : 1つ
#            生成回答  : 3つ
#
# [Image 45 | QA 6] 質問: ベビーカーを押してる人物の性別は何ですか？
#            正解      : 男性
#            生成回答  : 男性と女性がいます。
#
# [Image 45 | QA 7] 質問: 右端の建物の壁の色は何ですか？
#            正解      : 黄色
#            生成回答  : 緑色です。
#
#
# ====== [VQA] Image 46 の質問処理 ======
# [Image 46 | QA 0] 質問: 何の写真ですか？
#            正解      : ドーナツ
#            生成回答  : ドーナツの写真を撮りました。
#
# [Image 46 | QA 1] 質問: ドーナツはいくつ写っていますか？
#            正解      : みっつ
#            生成回答  : 2つ
#
# [Image 46 | QA 2] 質問: 下にしいてあるシートには何と書いてありますか？
#            正解      : DUNKIN' DONUTS
#            生成回答  : 「Dunkin' Donuts」と書いてあります。
#
# [Image 46 | QA 3] 質問: ドーナツをコーティングしているクリームは何色ですか？
#            正解      : 白
#            生成回答  : 白いクリームです。
#
# [Image 46 | QA 4] 質問: どんなドーナツですか？
#            正解      : クリームをぬったドーナツにクッキーをトッピングしてある
#            生成回答  : これは、チョコレートとオレオのフレーバーが特徴の、ドナツキンのドーナツです。
#
# [Image 46 | QA 5] 質問: ドーナツはどこに置かれていますか？
#            正解      : ワイヤーラックにしかれたシートの上
#            生成回答  : ドーナツは、ドーナツの紙で覆われた、金属製の棚に置かれています。
#
# [Image 46 | QA 6] 質問: ワイヤーラックの左手前には何がついていますか？
#            正解      : クリップ
#            生成回答  : 2つのオレオドーナツがワイヤーラックに並んでいます。
#
# [Image 46 | QA 7] 質問: 何と言うお店の写真だと思われますか？
#            正解      : DUNKIN' DONUTS
#            生成回答  : ダンキン・ドーナツの店です。
#
#
# ====== [VQA] Image 47 の質問処理 ======
# [Image 47 | QA 0] 質問: 雨はどれくらい降っていますか？
#            正解      : まったく降っていない
#            生成回答  : 画像には雨は降っていません。空は晴れています。
#
# [Image 47 | QA 1] 質問: どんな乗り物がありますか？
#            正解      : バイク
#            生成回答  : この画像には、モトクロスバイクとライダーが写っています。
#
# [Image 47 | QA 2] 質問: バイクはどんな特徴ですか？
#            正解      : モトクロス・バイク
#            生成回答  : この画像は、バイクに乗ったライダーが空中で体を逆さまにしている写真です。バイクは赤いフレームで、タイヤやサスペンションなど、オフロード走行に適したパーツが装着されています。
#
# [Image 47 | QA 3] 質問: 人は何人いますか？
#            正解      : 一人
#            生成回答  : それ以上
#
# [Image 47 | QA 4] 質問: どんな天気ですか？
#            正解      : 晴れ
#            生成回答  : 青空に雲があります。
#
# [Image 47 | QA 5] 質問: バイクは何台ありますか？
#            正解      : 一台
#            生成回答  : 1台です。
#
# [Image 47 | QA 6] 質問: バイカーの靴は何色ですか？
#            正解      : 白色
#            生成回答  : 白い靴です。
#
# [Image 47 | QA 7] 質問: バイカーのズボンは何色ですか？
#            正解      : 黒色
#            生成回答  : バイカーのズボンはピンク色です。
#
#
# ====== [VQA] Image 48 の質問処理 ======
# [Image 48 | QA 0] 質問: 窓は何枚ありますか？
#            正解      : 1枚
#            生成回答  : 窓は1枚です。
#
# [Image 48 | QA 1] 質問: ランプはいくつ点いていますか？
#            正解      : 1つ
#            生成回答  : 3つ
#
# [Image 48 | QA 2] 質問: ランプはどんな形ですか？
#            正解      : 丸型
#            生成回答  : ランプは円形です。
#
# [Image 48 | QA 3] 質問: 食器はどこに掛けてありますか？
#            正解      : 壁
#            生成回答  : 食器は壁に掛けてあります。
#
# [Image 48 | QA 4] 質問: 鍋はいくつありますか？
#            正解      : 2つ
#            生成回答  : 7つ
#
# [Image 48 | QA 5] 質問: フライ返しはいくつありますか？
#            正解      : 2つ
#            生成回答  : フライ返しは5つあります。
#
# [Image 48 | QA 6] 質問: おたまはいくつありますか？
#            正解      : 1つ
#            生成回答  : おたまは6つあります。
#
# [Image 48 | QA 7] 質問: 水切りかごは何色ですか？
#            正解      : 青
#            生成回答  : 青色です。
#
#
# ====== [VQA] Image 49 の質問処理 ======
# [Image 49 | QA 0] 質問: ここはどこですか？
#            正解      : テーブルの上
#            生成回答  : これは、木製のテーブルの上に置かれた携帯電話と手編みの手袋です。
#
# [Image 49 | QA 1] 質問: どんなテーブルですか？
#            正解      : 木製のテーブル
#            生成回答  : これは、木目調の明るい茶色のテーブルです。
#
# [Image 49 | QA 2] 質問: テーブルは何色ですか？
#            正解      : 黄褐色
#            生成回答  : 茶色です。
#
# [Image 49 | QA 3] 質問: テーブルの上には何がありますか？
#            正解      : 手袋と携帯電話が並んで置かれている
#            生成回答  : テーブルの上には、携帯電話と手編みの手袋があります。
#
# [Image 49 | QA 4] 質問: どんな手袋ですか？
#            正解      : 毛糸のミトン
#            生成回答  : 赤い手袋です。
#
# [Image 49 | QA 5] 質問: 手袋は何色ですか？
#            正解      : 赤
#            生成回答  : 赤い手袋です。
#
# [Image 49 | QA 6] 質問: どんな携帯電話ですか？
#            正解      : 折り畳み式の携帯電話
#            生成回答  : これはLGの古い折りたたみ携帯電話です。
#
# [Image 49 | QA 7] 質問: 携帯電話は何色ですか？
#            正解      : 銀色
#            生成回答  : 携帯電話は銀色です。
#
#
# ====== [VQA] Image 50 の質問処理 ======
# [Image 50 | QA 0] 質問: ここはどこですか？
#            正解      : 牧場
#            生成回答  : ここは牧草地です。
#
# [Image 50 | QA 1] 質問: 女性は何人いますか？
#            正解      : 0人
#            生成回答  : 3人います。
#
# [Image 50 | QA 2] 質問: 男性は何人いますか？
#            正解      : 0人
#            生成回答  : （この画像には男性はいません。牛が3頭います。）
#
# [Image 50 | QA 3] 質問: 人は何人いますか？
#            正解      : 0人
#            生成回答  : 3人
#
# [Image 50 | QA 4] 質問: 動物は何がいますか？
#            正解      : 牛
#            生成回答  : 牛と子牛がいます。
#
# [Image 50 | QA 5] 質問: 牛は何頭いますか？
#            正解      : 3頭
#            生成回答  : 3頭の牛がいます。
#
# [Image 50 | QA 6] 質問: 時間帯はいつごろですか？
#            正解      : 日中
#            生成回答  : 日中
#
# [Image 50 | QA 7] 質問: 天気はどういう状態ですか？
#            正解      : 晴れ
#            生成回答  : 晴れです。
#
#
# ====== [VQA] Image 51 の質問処理 ======
# [Image 51 | QA 0] 質問: 観覧車はどこにありますか
#            正解      : 木の向こう
#            生成回答  : 観覧車は、写真の背景にぼんやりと見えます。
#
# [Image 51 | QA 1] 質問: 空はどんな天気ですか
#            正解      : 曇り
#            生成回答  : 曇り空です。
#
# [Image 51 | QA 2] 質問: 赤いバスは何台ありますか
#            正解      : 二台
#            生成回答  : 3台の赤いバスがあります。
#
# [Image 51 | QA 3] 質問: 二階建てバスは何台ありますか
#            正解      : 二台
#            生成回答  : 二階建てバスは2台あります。
#
# [Image 51 | QA 4] 質問: 白いバスは何台ありますか
#            正解      : 二台
#            生成回答  : 2台の白いバスがあります。
#
# [Image 51 | QA 5] 質問: 緑の服を着ている人は何人いますか
#            正解      : 一人
#            生成回答  : 3人です。
#
# [Image 51 | QA 6] 質問: 黄色の服を着ている人は何人いますか
#            正解      : 一人
#            生成回答  : 3人です。
#
# [Image 51 | QA 7] 質問: 道路に何語が書かれていますか
#            正解      : 英語
#            生成回答  : 道路には「STOP」と書かれています。
#
#
# ====== [VQA] Image 52 の質問処理 ======
# [Image 52 | QA 0] 質問: 時計はどこにありますか。
#            正解      : 車道の左にある建物の壁面
#            生成回答  : 画像には時計がありません。
#
# [Image 52 | QA 1] 質問: 標識はどこにありますか。
#            正解      : 信号機の前
#            生成回答  : 標識は道路の右側にあります。
#
# [Image 52 | QA 2] 質問: 標識はどんな形をしていますか。
#            正解      : 三角形
#            生成回答  : 赤い三角形に「CEDA EL PASO」と書かれています。
#
# [Image 52 | QA 3] 質問: 信号機は何色が点灯していますか。
#            正解      : 赤
#            生成回答  : 赤色と黄色です。
#
# [Image 52 | QA 4] 質問: 車道にいる人が着ている服は何色ですか。
#            正解      : オレンジ色
#            生成回答  : 黄色い安全ベストを着ています。
#
# [Image 52 | QA 5] 質問: 車道の右端に停まっている車のうち、一番後ろに停まっている車は何色ですか。
#            正解      : 青
#            生成回答  : 青色です。
#
# [Image 52 | QA 6] 質問: 横断歩道の白い線は何本ですか。
#            正解      : 7本
#            生成回答  : 4本です。
#
# [Image 52 | QA 7] 質問: 歩道にいる人が着ている服は何色ですか。
#            正解      : 蛍光の黄色
#            生成回答  : 黄色い安全ベストを着ています。
#
#
# ====== [VQA] Image 53 の質問処理 ======
# [Image 53 | QA 0] 質問: どんな動物がいますか？
#            正解      : 犬
#            生成回答  : 犬です。
#
# [Image 53 | QA 1] 質問: 犬は、何匹いますか？
#            正解      : １匹
#            生成回答  : 犬は1匹です。
#
# [Image 53 | QA 2] 質問: 犬は、どんな色をしていますか？
#            正解      : 多くが白で顔やお尻に少し黒がある
#            生成回答  : 犬は白と黒をしています。
#
# [Image 53 | QA 3] 質問: 犬は、どこにいますか？
#            正解      : 柵の中の芝生の上
#            生成回答  : 犬は、芝生の上で飛び跳ねています。
#
# [Image 53 | QA 4] 質問: 犬は、何をしていますか？
#            正解      : 何かをくわえようとして前足を上げている
#            生成回答  : 犬は、ボールを追いかけています。
#
# [Image 53 | QA 5] 質問: 犬は、どんな物をくわえようとしていますか？
#            正解      : 何か白い物
#            生成回答  : 犬はボールをくわえようとしています。
#
# [Image 53 | QA 6] 質問: 誰かいますか？
#            正解      : 見物客
#            生成回答  : この画像には、観客とドッグフライングのイベントに参加している人々がいます。
#
# [Image 53 | QA 7] 質問: 見物客は、どれくらいいますか？
#            正解      : 数十人
#            生成回答  : 約30人
#
#
# ====== [VQA] Image 54 の質問処理 ======
# [Image 54 | QA 0] 質問: 天気は何ですか
#            正解      : 晴れです
#            生成回答  : 曇り
#
# [Image 54 | QA 1] 質問: 時間帯はいつですか
#            正解      : 日中です
#            生成回答  : 不明
#
# [Image 54 | QA 2] 質問: 場所はどこですか
#            正解      : スケボーができる公園です
#            生成回答  : ハワイ州ホノルルにあるスケートパークです。
#
# [Image 54 | QA 3] 質問: スケボーの男性はどんなふうに滑っていますか
#            正解      : 坂を上っているところです
#            生成回答  : スケボーの男性は、ランプを飛び越えながら、スケートパークのコースを滑っています。
#
# [Image 54 | QA 4] 質問: スケボーの男性はどんなズボンをはいていますか
#            正解      : ジーンズをはいています
#            生成回答  : 彼はジーンズをはいています。
#
# [Image 54 | QA 5] 質問: スケボーの男性は何色の靴をはいていますか
#            正解      : 白色です
#            生成回答  : 緑色の靴をはいています。
#
# [Image 54 | QA 6] 質問: スケボーをしている人以外にはどんな人がいますか
#            正解      : 自転車に乗っている人がいます
#            生成回答  : スケボーをしている人以外には、スケートボードをしている人、自転車に乗っている人、観覧している人、そして背景には芝生や木々、建物などがあります。
#
# [Image 54 | QA 7] 質問: スケボーの傾斜のついた坂は何色ですか
#            正解      : 茶色です
#            生成回答  : 茶色です。
#
#
# ====== [VQA] Image 55 の質問処理 ======
# [Image 55 | QA 0] 質問: 人は何人いますか？
#            正解      : 1人
#            生成回答  : それ以上
#
# [Image 55 | QA 1] 質問: どこに座っていますか？
#            正解      : ベンチ
#            生成回答  : 彼女は蝶の形のベンチに座っています。
#
# [Image 55 | QA 2] 質問: シャツはどんな色ですか？
#            正解      : ピンク
#            生成回答  : 紫色のシャツを着ています。
#
# [Image 55 | QA 3] 質問: どんな天気ですか？
#            正解      : 晴れ
#            生成回答  : 晴れです。
#
# [Image 55 | QA 4] 質問: 性別は何ですか？
#            正解      : 女性
#            生成回答  : 女性です。
#
# [Image 55 | QA 5] 質問: どんな表情をしていますか？
#            正解      : 笑顔
#            生成回答  : 彼女は微笑んでおり、少し自信があるように見えます。
#
# [Image 55 | QA 6] 質問: 何をモチーフにしたベンチですか？
#            正解      : 蝶
#            生成回答  : 蝶です。
#
# [Image 55 | QA 7] 質問: ベンチは何色ですか？
#            正解      : 茶色
#            生成回答  : ベンチは錆びた茶色です。
#
#
# ====== [VQA] Image 56 の質問処理 ======
# [Image 56 | QA 0] 質問: ここはどんな部屋ですか？
#            正解      : ユニットバス
#            生成回答  : これはバスルームです。
#
# [Image 56 | QA 1] 質問: 便器はいくつありますか？
#            正解      : 1つ
#            生成回答  : 1
#
# [Image 56 | QA 2] 質問: 洗面台はいくつありますか？
#            正解      : 1つ
#            生成回答  : 洗面台は1つです。
#
# [Image 56 | QA 3] 質問: 鏡は何枚ありますか？
#            正解      : 1枚
#            生成回答  : 鏡は1枚あります。
#
# [Image 56 | QA 4] 質問: ビンは何本ありますか？
#            正解      : 1本
#            生成回答  : 画像には、黒色のボトルが1本あります。
#
# [Image 56 | QA 5] 質問: シャワーカーテンはどんな柄ですか？
#            正解      : ストライプ
#            生成回答  : シャワーカーテンは、青と黄色のストライプ柄です。
#
# [Image 56 | QA 6] 質問: どんな色のマットが敷いてありますか？
#            正解      : 緑
#            生成回答  : 緑色のマットが敷いてあります。
#
# [Image 56 | QA 7] 質問: ビンはどこに置いてありますか？
#            正解      : 窓辺
#            生成回答  : ビンは、窓の近くに置かれています。
#
#
# ====== [VQA] Image 57 の質問処理 ======
# [Image 57 | QA 0] 質問: 天気はどんな天気ですか？
#            正解      : 雨
#            生成回答  : 雨模様です。
#
# [Image 57 | QA 1] 質問: 道路にひかれているラインの色は何色ですか？
#            正解      : 白色
#            生成回答  : 白です。
#
# [Image 57 | QA 2] 質問: 水色の傘の中に入っている人のうち、女性のＴシャツの色は何色ですか？
#            正解      : オレンジ色
#            生成回答  : 水色の傘の中に入っている人のうち、女性のＴシャツの色は白です。
#
# [Image 57 | QA 3] 質問: 画像右側手前の黄色い壁の建物についている外灯の形はどんな形ですか？
#            正解      : 円方
#            生成回答  : 外灯は、円錐形（またはコーン型）の、上部が絞られた形をしています。
#
# [Image 57 | QA 4] 質問: 画像右側手前の黄色い壁の建物についている外灯の数はいくつですか？
#            正解      : ７つ
#            生成回答  : **答え:** 5つ
#
# [Image 57 | QA 5] 質問: 右側の建物の前に停まっている自転車やバイクの手前においてあるものは何ですか？
#            正解      : 赤いカラーコーン
#            生成回答  : オレンジ色の三角錐です。
#
# [Image 57 | QA 6] 質問: 画像右側の黄色い壁の建物の隣の建物の７階に入っているお店の名前は何ですか？
#            正解      : アデランス
#            生成回答  : アプテラックス
#
# [Image 57 | QA 7] 質問: 右側の建物の前に停まっている自転車やバイクのすぐ横を歩いている人の帽子の色は何色ですか？
#            正解      : 白色
#            生成回答  : 青色です。
#
#
# ====== [VQA] Image 58 の質問処理 ======
# [Image 58 | QA 0] 質問: ここはどこ？
#            正解      : スキー場
#            生成回答  : スキー場です。
#
# [Image 58 | QA 1] 質問: 写真の男性はどんな状態？
#            正解      : スキーをしている
#            生成回答  : 男性はスキーを楽しんでいる様子です。
#
# [Image 58 | QA 2] 質問: スキーを滑っている人は全部で何人？
#            正解      : ２人
#            生成回答  : スキーを滑っている人は1人です。
#
# [Image 58 | QA 3] 質問: なし
#            正解      : なし
#            生成回答  : 画像はスキーヤーが雪上を滑走している様子を捉えています。
#
# [Image 58 | QA 4] 質問: なし
#            正解      : なし
#            生成回答  : 画像はスキーヤーが雪上を滑走している様子を捉えています。
#
# [Image 58 | QA 5] 質問: なし
#            正解      : なし
#            生成回答  : 画像はスキーヤーが雪上を滑走している様子を捉えています。
#
# [Image 58 | QA 6] 質問: なし
#            正解      : なし
#            生成回答  : 画像はスキーヤーが雪上を滑走している様子を捉えています。
#
# [Image 58 | QA 7] 質問: なし
#            正解      : なし
#            生成回答  : 画像はスキーヤーが雪上を滑走している様子を捉えています。
#
#
# ====== [VQA] Image 59 の質問処理 ======
# [Image 59 | QA 0] 質問: 階段に座っている人は、何人いますか？
#            正解      : ３人
#            生成回答  : 4人です。
#
# [Image 59 | QA 1] 質問: 手前の人は、何をしていますか？
#            正解      : スケートボード
#            生成回答  : スケートボードに乗って、ステップを踏んでいます。
#
# [Image 59 | QA 2] 質問: スケートボードをしている人は、何人いますか？
#            正解      : １人
#            生成回答  : 3人
#
# [Image 59 | QA 3] 質問: 木は、何本ありますか？
#            正解      : ２本
#            生成回答  : 画像には、少なくとも5本の木があります。
#
# [Image 59 | QA 4] 質問: 木の葉は、どういう状態ですか？
#            正解      : ない
#            生成回答  : 木の葉は、まだありません。これは、冬の画像です。
#
# [Image 59 | QA 5] 質問: どんな動物がいますか？
#            正解      : いない
#            生成回答  : この画像には、犬や猫などの動物は写っていません。スケートボードをしている人や、ベンチで座っている人々が写っています。
#
# [Image 59 | QA 6] 質問: 自転車は、何台ありますか？
#            正解      : ない
#            生成回答  : この画像には自転車はありません。
#
# [Image 59 | QA 7] 質問: 階段に座っている人の中で帽子をかぶった人は、何人いますか？
#            正解      : １人
#            生成回答  : 3人
#
#
# ====== [VQA] Image 60 の質問処理 ======
# [Image 60 | QA 0] 質問: 人間はどれくらいいますか？
#            正解      : 1人
#            生成回答  : 画像には1人のスノーボーダーがいます。
#
# [Image 60 | QA 1] 質問: スノーボードはどれくらいありますか？
#            正解      : 1つ
#            生成回答  : スノーボードは、この写真に写っているスノーボードの1枚です。
#
# [Image 60 | QA 2] 質問: 人間が乗っている物は何ですか？
#            正解      : スノーボード
#            生成回答  : スケートボードです。
#
# [Image 60 | QA 3] 質問: 人間が右手で掴んでいる物は何ですか？
#            正解      : スノーボード
#            生成回答  : スケートボードです。
#
# [Image 60 | QA 4] 質問: 人間が頭に被っている帽子はどんな色をしていますか？
#            正解      : 白と黒
#            生成回答  : 帽子は白と黒のボーダー柄です。
#
# [Image 60 | QA 5] 質問: 人間はどんな色のズボンを穿いていますか？
#            正解      : 黒色
#            生成回答  : グレーのズボンを穿いています。
#
# [Image 60 | QA 6] 質問: 人間はどんな色の靴を履いていますか？
#            正解      : 黒色
#            生成回答  : 黒と白の靴を履いています。
#
# [Image 60 | QA 7] 質問: 人間が頭に被っている物は何ですか？
#            正解      : 帽子
#            生成回答  : 帽子です。
#
#
# ====== [VQA] Image 61 の質問処理 ======
# [Image 61 | QA 0] 質問: 画像にはどんな乗り物のおもちゃが置いてありますか？
#            正解      : バス
#            生成回答  : バス
#
# [Image 61 | QA 1] 質問: 手前の人の人形はいくつありますか？
#            正解      : ３つ
#            生成回答  : 3人
#
# [Image 61 | QA 2] 質問: 手前の一番右側にある人の人形は何色の服を着ていますか？
#            正解      : 赤
#            生成回答  : 赤色の服を着ています。
#
# [Image 61 | QA 3] 質問: 手前の中央にある人の人形は何色の服を着ていますか？
#            正解      : 黄色
#            生成回答  : 赤い服を着ています。
#
# [Image 61 | QA 4] 質問: 手前の一番左側にある人の人形は何色の服を着ていますか？
#            正解      : 白色
#            生成回答  : 白い服を着ています。
#
# [Image 61 | QA 5] 質問: バスはどこ方向へ走っていますか？
#            正解      : 右方向
#            生成回答  : バスは右方向へ走っています。
#
# [Image 61 | QA 6] 質問: 画像にはタイヤはいくつ写っていますか？
#            正解      : ２つ
#            生成回答  : 4
#
# [Image 61 | QA 7] 質問: 奥の建物は何色ですか？
#            正解      : 赤茶色
#            生成回答  : 赤色です。
#
#
# ====== [VQA] Image 62 の質問処理 ======
# [Image 62 | QA 0] 質問: 動物はどれくらいいますか。
#            正解      : たくさんいます。
#            生成回答  : たくさんの羊がいます。
#
# [Image 62 | QA 1] 質問: 動物は何がいますか。
#            正解      : ヤギです。
#            生成回答  : 羊です。
#
# [Image 62 | QA 2] 質問: 右手前にいるヤギは何色ですか。
#            正解      : 白です。
#            生成回答  : 白い。
#
# [Image 62 | QA 3] 質問: 人は何人いますか。
#            正解      : ひとりもいません。
#            生成回答  : 画像には多くの羊が写っていますが、明確に人間の姿は見えません。したがって、人間の数は0人です。
#
# [Image 62 | QA 4] 質問: ヤギはどうなっていますか。
#            正解      : かたまっています。
#            生成回答  : ヤギは
#
# [Image 62 | QA 5] 質問: 建物はいくつありますか。
#            正解      : ひとつもありません。
#            生成回答  : 画像には建物は写っていません。
#
# [Image 62 | QA 6] 質問: ヤギの耳に何がついていますか。
#            正解      : タグがついています。
#            生成回答  : ヤギの耳にタグが付いています。
#
# [Image 62 | QA 7] 質問: 右手前にいるヤギのタグは何色ですか。
#            正解      : ピンクです。
#            生成回答  : 青色
#
#
# ====== [VQA] Image 63 の質問処理 ======
# [Image 63 | QA 0] 質問: 何人の人がいますか？
#            正解      : 1人
#            生成回答  : わからない

# %% [markdown]
# SakanaAI/JA-VG-VQA-500のデータすべて使って実験したところ、
# 上記の状況下でColab の使用量上限に達した。

# %%
for r in vg_results[:10]:
    print(r)
# Out:
# {'question': '場所はどこになりますか？', 'gt_answer': '車のある屋外の場所', 'pred_answer': 'この画像は、オーストラリアの海岸沿いの道路に駐車された白いトラックの前に置かれたサーフボードを撮影したものです。背景には海と砂浜が見えます。'}
# {'question': '時間帯はいつごろですか？', 'gt_answer': '昼間', 'pred_answer': '時間帯は不明'}
# {'question': 'どんな天気をしていますか？', 'gt_answer': '晴れている', 'pred_answer': '晴れです。'}
# {'question': '車は何台ありますか？', 'gt_answer': '1台', 'pred_answer': '1台です。'}
# {'question': '車はどんな色をしていますか？', 'gt_answer': '白色', 'pred_answer': '白い車です。'}
# {'question': 'サーフボードはいくつありますか？', 'gt_answer': '1つ', 'pred_answer': '画像にはサーフボードが1枚あります。'}
# {'question': 'サーフボードはどんな色をしていますか？', 'gt_answer': '白色', 'pred_answer': 'サーフボードは白です。'}
# {'question': '車の向こう側には何が見えますか？', 'gt_answer': '青い海と青い空が広がっているのが見える', 'pred_answer': '車の向こう側には、海と砂浜が見えます。'}
# {'question': 'ここはどこですか？', 'gt_answer': '池のほとりです。', 'pred_answer': 'この画像は、イギリスのロンドンにある、ボタニック・ガーデンに隣接する、リバー・グレン（River Glen）の風景です。'}
# {'question': '池には何がいますか？', 'gt_answer': '鴨がいます。', 'pred_answer': '池には、水面に浮かぶアヒルがいます。'}

# %%
evaluate_metric(vg_results, "JA-VG-VQA-500")
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
#  Evaluation for JA-VG-VQA-500 (ROUGE-L)
#  - Rouge-L Score : 0.0833

# %% [markdown]
# 上記の0.0833は</br>
# vg_dataset = load_dataset("SakanaAI/JA-VG-VQA-500", split="test[:3]")</br>
# つまり、データの先頭3件だけ取得したときの結果となっている

# %% [markdown]
# ## JA-VLM-Bench-In-the-Wild

# %%
# 2. JA-VLM-Bench-In-the-Wild
vlm_dataset = load_dataset("SakanaAI/JA-VLM-Bench-In-the-Wild", split="test")

# %%
vlm_dataset
# Out:
# Dataset({
#     features: ['page_url', 'image_url', 'image', 'question', 'answer'],
#     num_rows: 3
# })

# %%
def infer_ja_vlm_bench_wild(dataset):
    """
    1画像1質問の形式（SakanaAI/JA-VLM-Bench-In-the-Wild）に対応した推論関数。
    各行に対して画像+質問を渡し、推論結果と正解を記録する。
    """
    results = []

    for idx, item in enumerate(dataset):
        image = item["image"].convert("RGB")
        question = item["question"]
        gt_answer = item.get("answer", None)

        print(f"\n====== [VQA] Entry {idx} - 質問処理開始 ======")

        result = generate_vqa_answer(image, question, gt_answer)
        results.append(result)

        # 中間出力（統一形式）
        print(f"[Entry {idx}] 質問: {question}")
        print(f"           正解      : {gt_answer}")
        print(f"           生成回答  : {result['pred_answer']}\n")

    return results

# %%
vlm_results = infer_ja_vlm_bench_wild(vlm_dataset)
# Out:
# ====== [VQA] Entry 0 - 質問処理開始 ======
# [Entry 0] 質問: この写真はどこの国で撮影されましたか？
#            正解      : この写真は日本で撮影されました。
#            生成回答  : 日本
#
#
# ====== [VQA] Entry 1 - 質問処理開始 ======
# [Entry 1] 質問: この自動販売機にはどのブランドの飲料が含まれていますか？
#            正解      : キリンの飲料が含まれています。
#            生成回答  : キリン
#
#
# ====== [VQA] Entry 2 - 質問処理開始 ======
# [Entry 2] 質問: この写真に写っている有名な建物の名前は何ですか？
#            正解      : 東京タワーです。
#            生成回答  : 東京タワーです。
#
#
# ====== [VQA] Entry 3 - 質問処理開始 ======
# [Entry 3] 質問: この写真にはどんな植物が映っていますか？
#            正解      : 桜の花が映っています。
#            生成回答  : 桜の花が映っています。
#
#
# ====== [VQA] Entry 4 - 質問処理開始 ======
# [Entry 4] 質問: この写真に写っているタワーは何ですか？
#            正解      : この写真には東京スカイツリーが写っています。
#            生成回答  : 東京タワーです。
#
#
# ====== [VQA] Entry 5 - 質問処理開始 ======
# [Entry 5] 質問: この駅は何線のものですか？
#            正解      : 画像から正確な路線名は読み取れませんが、京都へ行く電車のある駅であることが分かります。
#            生成回答  : この駅は4線の駅です。
#
#
# ====== [VQA] Entry 6 - 質問処理開始 ======
# [Entry 6] 質問: この駅のホームには何番線がありますか？
#            正解      : 1番線と2番線があります。
#            生成回答  : 2番線です。
#
#
# ====== [VQA] Entry 7 - 質問処理開始 ======
# [Entry 7] 質問: 画像に何が見えますか？
#            正解      : 日本の伝統的な建物の前に野菜と果物が置かれてある光景が見えます。店の前には、レモンやトマト、ネギなどが置いてあり、提灯とメニューが掲げられています。
#            生成回答  : この画像には、日本の古い町並みに佇む食堂の入り口が見えます。食堂の正面には、木製の壁に格子戸があり、メニューが掲示されています。正面には、野菜や玉ねぎなどが積まれた木製のテーブルと椅子があり、食堂の食材をアピールしています。また、提灯や看板など、日本の伝統的な要素も確認できます。
#
#
# ====== [VQA] Entry 8 - 質問処理開始 ======
# [Entry 8] 質問: この画像には何個の提灯がありますか？
#            正解      : 15個の提灯があります。
#            生成回答  : 18個
#
#
# ====== [VQA] Entry 9 - 質問処理開始 ======
# [Entry 9] 質問: この自動販売機にはどんな種類の飲み物がありますか？
#            正解      : この自動販売機にはコーヒー、お茶、ジュース、スポーツドリンク、ミルクティーがあります。
#            生成回答  : この自動販売機には、コカ・コーラ、リアルゴールド、ファンタ、ビンテ、カレス、ジョージア、コーンポタージュ、そして様々なフレーバーのジュースやコーヒーなどが揃っています。
#
#
# ====== [VQA] Entry 10 - 質問処理開始 ======
# [Entry 10] 質問: この画像に写っている道路の制限速度は何キロメートルですか？
#            正解      : 30キロメートルです。
#            生成回答  : 30キロメートル
#
#
# ====== [VQA] Entry 11 - 質問処理開始 ======
# [Entry 11] 質問: この店は主にどんな商品を扱っていますか？
#            正解      : この店はゲームやおもちゃを扱っているようです。
#            生成回答  : この店は、主に自動販売機で様々な商品を販売しています。
#
#
# ====== [VQA] Entry 12 - 質問処理開始 ======
# [Entry 12] 質問: この店の外には何色の風船がありますか？
#            正解      : 緑、黄、赤、紫、青の風船があります。
#            生成回答  : 青と紫の風船があります。
#
#
# ====== [VQA] Entry 13 - 質問処理開始 ======
# [Entry 13] 質問: この写真に写っている建物は何ですか？
#            正解      : この写真には金閣寺が写っています。
#            生成回答  : 金閣寺（きんかくじ）です。
#
#
# ====== [VQA] Entry 14 - 質問処理開始 ======
# [Entry 14] 質問: 写真に写っている人々はどのような服を着ていますか？
#            正解      : 写真に写っている人々は着物を着ています。
#            生成回答  : 写真に写っている人々は、着物（和服）を着ています。
#
#
# ====== [VQA] Entry 15 - 質問処理開始 ======
# [Entry 15] 質問: この彫刻に表されているテーマは何ですか？
#            正解      : 「見ざる、聞かざる、言わざる」がテーマです。この三匹の猿はそれぞれ目、耳、口を覆っており、悪いものを見ず、聞かず、言わないことを象徴しています。
#            生成回答  : この彫刻は、仏教の教えである「眼隠（げんおん）」の概念を表しています。眼隠とは、知性や知識を隠し、悟りを開くための修行法です。この彫刻の３匹の猿は、それぞれ自分の目を覆い、知性を隠している姿で、この修行法を示唆しています。
#
#
# ====== [VQA] Entry 16 - 質問処理開始 ======
# [Entry 16] 質問: この写真に写っている人は何人ですか？
#            正解      : 4人です。
#            生成回答  : 4人です。
#
#
# ====== [VQA] Entry 17 - 質問処理開始 ======
# [Entry 17] 質問: この画像に写っている人々はどのような服を着ていますか？
#            正解      : この画像の人々は日本の伝統的な服装である着物を着ています。女性はそれぞれ異なる色と柄の着物を着ており、右側にいる男性は青い色の柄入りの浴衣を着ています。
#            生成回答  : この画像には、4人の女性と1人の男性が写っています。女性たちは着物（和服）を着ており、男性は着物と刀（katana）を持っています。
#
#
# ====== [VQA] Entry 18 - 質問処理開始 ======
# [Entry 18] 質問: この八百屋さんで売られているパイナップルの価格はいくらですか？
#            正解      : パイナップルの価格は198円です。
#            生成回答  : 価格は198円です。
#
#
# ====== [VQA] Entry 19 - 質問処理開始 ======
# [Entry 19] 質問: この写真にはどのような果物が売られていますか？
#            正解      : パイナップル、みかん、柿が売られています。
#            生成回答  : この写真には、パイナップルとオレンジが売られています。
#
#
# ====== [VQA] Entry 20 - 質問処理開始 ======
# [Entry 20] 質問: この画像に写っているタワーの名前は何ですか？
#            正解      : 通天閣です。
#            生成回答  : 東京タワー
#
#
# ====== [VQA] Entry 21 - 質問処理開始 ======
# [Entry 21] 質問: この画像にはどんな食事が写っていますか？
#            正解      : この画像には、とんかつが卵と玉ねぎと一緒に鉄鍋で提供されている「かつ丼」と、横にご飯とみそ汁が写っています。
#            生成回答  : この画像には、鶏肉の唐揚げと卵焼きが乗ったどんぶりに、ご飯、味噌汁、お新香などが添えられた日本の定食が写っています。
#
#
# ====== [VQA] Entry 22 - 質問処理開始 ======
# [Entry 22] 質問: この画像に写っている傘は何色ですか？
#            正解      : 白い色です。
#            生成回答  : 白い傘が4本並んでいます。
#
#
# ====== [VQA] Entry 23 - 質問処理開始 ======
# [Entry 23] 質問: この店はどんな食品を主に販売していますか？
#            正解      : 揚げ物を主に販売しています。
#            生成回答  : この店は、主に焼き鳥（ヤキトリ）を販売しています。
#
#
# ====== [VQA] Entry 24 - 質問処理開始 ======
# [Entry 24] 質問: この写真に写っている店の色は何色ですか？
#            正解      : 赤色です。
#            生成回答  : 赤い色です。
#
#
# ====== [VQA] Entry 25 - 質問処理開始 ======
# [Entry 25] 質問: この画像に映っている魚の形をした飾りは、日本では何と呼ばれていますか？
#            正解      : これらは「こいのぼり」と呼ばれています。
#            生成回答  : これらの魚の形をした飾りは、日本で「河童（かっぱ）」と呼ばれています。
#
#
# ====== [VQA] Entry 26 - 質問処理開始 ======
# [Entry 26] 質問: この写真に写っている標識の色は何ですか？
#            正解      : 赤色と青色です。
#            生成回答  : 青と白、赤です。
#
#
# ====== [VQA] Entry 27 - 質問処理開始 ======
# [Entry 27] 質問: この画像にはどんな標識が写っていますか？
#            正解      : 画像には「進入禁止」の標識と、左矢印がある「一方通行」の標識が写っています。下部には「自転車を除く」という補助標識もあります。
#            生成回答  : この画像には、左折禁止の標識、方向を示す標識、および日本語の文字が書かれた標識が写っています。
#
#
# ====== [VQA] Entry 28 - 質問処理開始 ======
# [Entry 28] 質問: この画像に写っているものは何ですか？
#            正解      : 日本酒の瓶が4本写っています。
#            生成回答  : 写っているのは、日本の清酒（日本酒）の瓶が4本です。
#
#
# ====== [VQA] Entry 29 - 質問処理開始 ======
# [Entry 29] 質問: この写真にはどんな文字が書かれていますか？
#            正解      : 「そばうどん」と書かれています。
#            生成回答  : 写真には「そばうどん」という文字が書かれた提灯が飾られています。
#
#
# ====== [VQA] Entry 30 - 質問処理開始 ======
# [Entry 30] 質問: 画像に写っている車のナンバープレートの数字は何ですか？
#            正解      : 18-22です。
#            生成回答  : 18-22
#
#
# ====== [VQA] Entry 31 - 質問処理開始 ======
# [Entry 31] 質問: この写真に写っている動物は何ですか？
#            正解      : 写真には鹿が2匹写っています。
#            生成回答  : 鹿です。
#
#
# ====== [VQA] Entry 32 - 質問処理開始 ======
# [Entry 32] 質問: この看板に表示されている店舗は何ですか？
#            正解      : マクドナルドの店舗です。
#            生成回答  : マクドナルドGinza 168号店
#
#
# ====== [VQA] Entry 33 - 質問処理開始 ======
# [Entry 33] 質問: このお皿の上には何がのっていますか？
#            正解      : お皿の上にはクッキーが2枚のっています。
#            生成回答  : お皿の上には、ゾウの形をしたクッキーが3枚あります。
#
#
# ====== [VQA] Entry 34 - 質問処理開始 ======
# [Entry 34] 質問: この画像にはどのような乗り物が写っていますか？
#            正解      : タクシーが写っています。
#            生成回答  : タクシーと自動車が写っています。
#
#
# ====== [VQA] Entry 35 - 質問処理開始 ======
# [Entry 35] 質問: この画像に写っている山は何でしょうか？
#            正解      : 富士山です。
#            生成回答  : 富士山です。
#
#
# ====== [VQA] Entry 36 - 質問処理開始 ======
# [Entry 36] 質問: このお店は何を売っていると思いますか？
#            正解      : このお店は中古の本やCD、ビデオゲームなどを売っています。
#            生成回答  : このお店は、文房具、ホビー用品、ゲーム、CD、DVDなどを販売している日本の大型ディスカウントストア「Don Quijote」のホビー用品専門店「Don Quijote Hobby One」です。
#
#
# ====== [VQA] Entry 37 - 質問処理開始 ======
# [Entry 37] 質問: 店の名前は何ですか？
#            正解      : 店の名前は「BOOK-OFF」です。
#            生成回答  : Ok-Off Hobby O
#
#
# ====== [VQA] Entry 38 - 質問処理開始 ======
# [Entry 38] 質問: この看板に書かれている絵はどのような特徴を持っていますか？
#            正解      : この標識には、横断歩道を渡る人の絵が描かれており、顔には何かしらのステッカーが貼られていて、その結果、人の顔がダイビング用のゴーグルをつけているように見えます。
#            生成回答  : この看板は、歩行者用横断歩道を示す一般的な歩行者標識ですが、その上に奇妙な顔（大きな目と口）が描かれています。
#
#
# ====== [VQA] Entry 39 - 質問処理開始 ======
# [Entry 39] 質問: この写真にはどのようなものが木についていますか？
#            正解      : テントウムシの形をしたオブジェクトが木についています。
#            生成回答  : 木には、赤いボディと黒いスポットが特徴の瓢虫の形をした金属製の容器がついています。
#
#
# ====== [VQA] Entry 40 - 質問処理開始 ======
# [Entry 40] 質問: この写真に写っている歴史的な建物は何ですか？
#            正解      : この写真には東京駅の丸の内駅舎が写っています。
#            生成回答  : 東京駅です。
#
#
# ====== [VQA] Entry 41 - 質問処理開始 ======
# [Entry 41] 質問: この人はどこにいますか？
#            正解      : バス停にいます。
#            生成回答  : 彼はバス停にいます。
#
#
# ====== [VQA] Entry 42 - 質問処理開始 ======
# [Entry 42] 質問: この写真に写っているバスは何色ですか？
#            正解      : バスはオレンジ色です。
#            生成回答  : オレンジ色です。
#
#
# ====== [VQA] Entry 43 - 質問処理開始 ======
# [Entry 43] 質問: この画像にはどんな植物が写っていますか？
#            正解      : ひまわりが写っています。
#            生成回答  : この画像には、ヒマワリが写っています。
#
#
# ====== [VQA] Entry 44 - 質問処理開始 ======
# [Entry 44] 質問: この女性は何をしていますか？
#            正解      : バイオリンを演奏しています。
#            生成回答  : 彼女はヴァイオリンを演奏しています。
#
#
# ====== [VQA] Entry 45 - 質問処理開始 ======
# [Entry 45] 質問: 画像には何匹の猿がいますか？
#            正解      : 2匹の猿がいます。
#            生成回答  : 画像には2匹の猿がいます。
#
#
# ====== [VQA] Entry 46 - 質問処理開始 ======
# [Entry 46] 質問: この写真に映っている建物は何と呼ばれていますか？
#            正解      : 合掌造りの家です。
#            生成回答  : この写真に映っている建物は、茅葺き屋根の町家です。
#
#
# ====== [VQA] Entry 47 - 質問処理開始 ======
# [Entry 47] 質問: この駐車場の利用可能時間は何時から何時までですか？
#            正解      : この駐車場は8時から20時まで利用可能です。
#            生成回答  : 駐車場の利用可能時間は8時から20時までです。
#
#
# ====== [VQA] Entry 48 - 質問処理開始 ======
# [Entry 48] 質問: この画像にはどんなアイテムが砂浜に置かれていますか？
#            正解      : 2足のサンダルが砂浜に置かれています。
#            生成回答  : 砂浜にサンダルが2つ置かれています。
#
#
# ====== [VQA] Entry 49 - 質問処理開始 ======
# [Entry 49] 質問: この画像にはどんな機械が写っていますか？
#            正解      : 画像にはガチャガチャと呼ばれるカプセルトイの自動販売機が写っています。
#            生成回答  : この画像には、日本の公園などで見られる、おしりを拭くためのウェットティッシュを販売する自動販売機が写っています。

# %%
for r in vlm_results[:10]:
    print(r)
# Out:
# {'question': 'この写真はどこの国で撮影されましたか？', 'gt_answer': 'この写真は日本で撮影されました。', 'pred_answer': '日本'}
# {'question': 'この自動販売機にはどのブランドの飲料が含まれていますか？', 'gt_answer': 'キリンの飲料が含まれています。', 'pred_answer': 'キリン'}
# {'question': 'この写真に写っている有名な建物の名前は何ですか？', 'gt_answer': '東京タワーです。', 'pred_answer': '東京タワーです。'}
# {'question': 'この写真にはどんな植物が映っていますか？', 'gt_answer': '桜の花が映っています。', 'pred_answer': '桜の花が映っています。'}
# {'question': 'この写真に写っているタワーは何ですか？', 'gt_answer': 'この写真には東京スカイツリーが写っています。', 'pred_answer': '東京タワーです。'}
# {'question': 'この駅は何線のものですか？', 'gt_answer': '画像から正確な路線名は読み取れませんが、京都へ行く電車のある駅であることが分かります。', 'pred_answer': 'この駅は4線の駅です。'}
# {'question': 'この駅のホームには何番線がありますか？', 'gt_answer': '1番線と2番線があります。', 'pred_answer': '2番線です。'}
# {'question': '画像に何が見えますか？', 'gt_answer': '日本の伝統的な建物の前に野菜と果物が置かれてある光景が見えます。店の前には、レモンやトマト、ネギなどが置いてあり、提灯とメニューが掲げられています。', 'pred_answer': 'この画像には、日本の古い町並みに佇む食堂の入り口が見えます。食堂の正面には、木製の壁に格子戸があり、メニューが掲示されています。正面には、野菜や玉ねぎなどが積まれた木製のテーブルと椅子があり、食堂の食材をアピールしています。また、提灯や看板など、日本の伝統的な要素も確認できます。'}
# {'question': 'この画像には何個の提灯がありますか？', 'gt_answer': '15個の提灯があります。', 'pred_answer': '18個'}
# {'question': 'この自動販売機にはどんな種類の飲み物がありますか？', 'gt_answer': 'この自動販売機にはコーヒー、お茶、ジュース、スポーツドリンク、ミルクティーがあります。', 'pred_answer': 'この自動販売機には、コカ・コーラ、リアルゴールド、ファンタ、ビンテ、カレス、ジョージア、コーンポタージュ、そして様々なフレーバーのジュースやコーヒーなどが揃っています。'}

# %%
evaluate_metric(vlm_results, "JA-VLM-Bench-In-the-Wild")
# Out:
#  Evaluation for JA-VLM-Bench-In-the-Wild (ROUGE-L)
#  - Rouge-L Score : 0.1844

# %% [markdown]
# ## ファインチューニング

# %%
from datasets import load_dataset

dataset = load_dataset("line-corporation/JIC-VQA", split="train[:10]")
print(dataset.features)
# Out:
# README.md:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# jafacility20.csv:   0%|          | 0.00/291k [00:00<?, ?B/s]
# jaflower30.csv:   0%|          | 0.00/664k [00:00<?, ?B/s]
# jafood101.csv:   0%|          | 0.00/1.41M [00:00<?, ?B/s]
# jalandmark10.csv:   0%|          | 0.00/324k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7654 [00:00<?, ? examples/s]
# {'id': Value(dtype='int64', id=None), 'license': Value(dtype='string', id=None), 'license_url': Value(dtype='string', id=None), 'url': Value(dtype='string', id=None), 'category': Value(dtype='string', id=None), 'question': Value(dtype='string', id=None)}

# %%
print(dataset[0])
# Out:
# {'id': 11190751074, 'license': 'Attribution License', 'license_url': 'https://creativecommons.org/licenses/by/2.0/', 'url': 'https://live.staticflickr.com/5536/11190751074_f97587084e_o.jpg', 'category': 'ガソリンスタンド', 'question': "この画像にはどの施設が映っていますか？次の四つの選択肢から正しいものを選んでください: ['スーパーマーケット', 'コンビニ', '駐車場', 'ガソリンスタンド']", 'messages': [{'content': 'あなたは優秀な日本語ビジュアルアシスタントです。画像についての質問に丁寧に答えてください。', 'role': 'system'}, {'content': " この画像にはどの施設が映っていますか？次の四つの選択肢から正しいものを選んでください: ['スーパーマーケット', 'コンビニ', '駐車場', 'ガソリンスタンド']", 'role': 'user'}, {'content': 'ガソリンスタンド', 'role': 'assistant'}], 'text': "<s>[SYSTEM] あなたは優秀な日本語ビジュアルアシスタントです。画像についての質問に丁寧に答えてください。\n[USER]  この画像にはどの施設が映っていますか？次の四つの選択肢から正しいものを選んでください: ['スーパーマーケット', 'コンビニ', '駐車場', 'ガソリンスタンド']\n[ASSISTANT] ガソリンスタンド</s>"}

# %% [markdown]
# ファインチューニングをするための実装を実験していましたが、上手くいかなかったため断念

# %% [markdown]
# ## 苦戦した点
#
# 本プロジェクトを進める中で、いくつかの技術的・運用的な課題に直面し、解決に時間を要した。以下に主な苦戦点を整理する。
#
# 1. 画像とテキストを組み合わせてモデルに入力し、推論を行う実装の構築に時間がかかった。
# マルチモーダルな入力を正しく処理するためのプロンプト設計や、前処理（画像のRGB変換など）に習熟する必要があり、試行錯誤を繰り返した。
#
# 2. ベンチマーク評価の方法を調査するのに時間を要した。
# 特にROUGEスコアなどの自動評価指標の扱い方や、どのような条件で評価が行われるのかを理解するまでに苦労した。
#
# 3. ベンチマーク評価の結果に違和感があり、コードや処理ロジックの確認、さらにはGPUメモリの制限による処理失敗への対応に時間を要した。
# データセットの件数が多くなるとGPUメモリを超過するため、バッチサイズや処理単位の調整を検討する必要があった。
#
# 4. Heron-Benchについて調査した際、GPT-4を用いた評価プロセス（生成された2つの回答を比較し、GPT-4が点数を付与する方式）の理解に時間がかかった。
# さらに、GPT-4の使用にはコストがかかるため、予算の計算やAPI利用準備などを含めた検討も必要となった。結果的に、この評価方法は後回しとし、今回は実施を見送った。
#
# 5. VLM（Vision-Language Model）のファインチューニングを可能にする実装方法の調査にも多くの時間を要した。
# 特に、マルチモーダル入力に対応するモデル構造の改変や、LoRAなどの軽量ファインチューニング手法の適用に多くの技術的課題が存在し、実装が思うように進まなかった。

# %% [markdown]
# ## 参考資料：
#
# *   https://huggingface.co/google/gemma-3-4b-it
# *   https://huggingface.co/datasets/SakanaAI/JA-VLM-Bench-In-the-Wild
# *   https://huggingface.co/datasets/SakanaAI/JA-VG-VQA-500
# *   https://huggingface.co/datasets/turing-motors/Japanese-Heron-Bench
# *   https://huggingface.co/datasets/line-corporation/JIC-VQA
# *   https://qiita.com/tinymouse/items/1c5d49579e95369b1d0b
# *   https://note.com/owlet_notes/n/na7416b0414b7
# *   https://zenn.dev/watamoo/articles/0590ad46d7b26b
